# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import random
import numpy as np
import tensorflow as tf

# %%
# load in some text to use
shakes = open('data/shakespeare.txt', 'r').read()
print(shakes[0:1000])
# Out:
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You are all resolved rather to die than to famish?
#
# All:
# Resolved. resolved.
#
# First Citizen:
# First, you know Caius Marcius is chief enemy to the people.
#
# All:
# We know't, we know't.
#
# First Citizen:
# Let us kill him, and we'll have corn at our own price.
# Is't a verdict?
#
# All:
# No more talking on't; let it be done: away, away!
#
# Second Citizen:
# One word, good citizens.
#
# First Citizen:
# We are accounted poor citizens, the patricians good.
# What authority surfeits on would relieve us: if they
# would yield us but the superfluity, while it were
# wholesome, we might guess they relieved us humanely;
# but they think we are too dear: the leanness that
# afflicts us, the object of our misery, is as an
# inventory to particularise their abundance; our
# sufferance is a gain to them Let us revenge this with
# our pikes, ere we become rakes: for the gods know I
# speak this in hunger for bread, not in thirst for revenge.

# %%
# need to get all of the possible characters that the source uses
chars = list(set(shakes))
data_size, vocab_size = len(shakes), len(chars)
print('Text is', data_size, 'characters long and there are', vocab_size, 'unique characters.')
# Out:
# Text is 1115394 characters long and there are 65 unique characters.

# %%
# create dictionaries to convert from characters to index and from index back to characters
char2idx = {ch: i for i, ch in enumerate(chars)}
idx2char = {i: ch for i, ch in enumerate(chars)}

# %%
# define some hyperparameters for our network
hidden_size = 256
seq_length = 50
epochs = 1000

# %% [markdown]
# # Building a GRU in tensorflow
#
# In this final notebook we'll work in Tensorflow directly. I would recommend getting familiar with how neural networks work by using our previous examples and then once you feel comfortable with Keras and all of the high level concepts move into Tensorflow.
#
# Tensorflow does give us a few helper functions to facilitate the construction of neural networks, but mostly we will be building lots of things from scratch. The one thing that we definitely don't want to do is calculate the backward pass for our training steps, luckily this is something that Tensorflow will do for us.
#
# In this example we will create a GRU recurrent neural network to use in our character level RNN. The steps for creating this network from scratch will be:
#
# * Initialize all of our weight matrices. Setup their sizes and fill with random numbers
# * Define the calculations that our network must carry out
#
# A GRU cell is basically a change in the way that the hidden state is calculated for a recurrent neural network. So to begin we'll start with a vanilla recurrent neural network and show how we can create one using the two steps above.
#
# ### Vanilla RNN
#
# The calculations for a recurrent neural network look like the following:
#
# ![rnn](images/rnn.png)
#
# In order to create that we need to set up three matrices and two bias vectors. The specify the calculations in exactly the same way.
#
# ```python
# Uh = tf.get_variable("Uh", [input_size, hidden_size], initializer=tf.random_normal_initializer(stddev=0.1))
# Wh = tf.get_variable("Wh", [hidden_size, hidden_size], initializer=tf.random_normal_initializer(stddev=0.1))
# Vy = tf.get_variable("Vy", [hidden_size, vocab_size], initializer=tf.random_normal_initializer(stddev=0.1))
# bh  = tf.get_variable("bh", [hidden_size], initializer=tf.random_normal_initializer(stddev=0.1))
# by  = tf.get_variable("by", [output_size], initializer=tf.random_normal_initializer(stddev=0.1))
#
# hs_t = tf.tanh(tf.matmul(xs_t, Uh) + tf.matmul(hs_t, Wh) + bh)
# ys_t = tf.nn.softmax(tf.matmul(hs_t, Vy) + by)
# ```
#
# Simple enough. Input_size and output_size will change depending on the properties of our data. Hidden_size is a hyperparameter that we can set to anything that we wish.
#
# ### Gated Recurrent Unit
#
# The changes to go from a vanilla RNN to a GRU are made to the way that we calculate the hidden state. Therefore, we will keep all of the matrices that we set up earlier and just add in what we need for the GRU calcualtions. The GRU calculations look as follows:
#
# ![gru](images/GRU.png)
#
# Lets add in what we need.
#
# ```python
# # weight from input to hidden for z gate
# Uz = tf.get_variable("Uz", [vocab_size, hidden_size], initializer=tf.random_normal_initializer(stddev=0.1))
# # weight from hidden to hidden for z gate
# Wz = tf.get_variable("Wz", [hidden_size, hidden_size], initializer=tf.random_normal_initializer(stddev=0.1))
# # bias for the z gate calculation
# bz = tf.get_variable("bz", [hidden_size], initializer=tf.random_normal_initializer(stddev=0.1))
#
# # weight from input to hidden for r gate
# Ur = tf.get_variable("Ur", [vocab_size, hidden_size], initializer=tf.random_normal_initializer(stddev=0.1))
# # weight from hidden to hidden for r gate
# Wr = tf.get_variable("Wr", [hidden_size, hidden_size], initializer=tf.random_normal_initializer(stddev=0.1))
# # bias for the r gate calculation
# br = tf.get_variable("br", [hidden_size], initializer=tf.random_normal_initializer(stddev=0.1))
#
# # weight from input to hidden
# Uh = tf.get_variable("Uh", [vocab_size, hidden_size], initializer=tf.random_normal_initializer(stddev=0.1))
#
# # recurrent weight matrix, hidden 2 hidden
# Wh = tf.get_variable("Wh", [hidden_size, hidden_size], initializer=tf.random_normal_initializer(stddev=0.1))
# # bias for hidden matrix
# bh = tf.get_variable("bh", [hidden_size], initializer=tf.random_normal_initializer(stddev=0.1))
#
# # output weight matrix
# Vy = tf.get_variable("Vy", [hidden_size, vocab_size], initializer=tf.random_normal_initializer(stddev=0.1))
# # bias for output matrix
# by = tf.get_variable("by", [vocab_size], initializer=tf.random_normal_initializer(stddev=0.1))
#
# # perform the z gate calculation
# zt = tf.sigmoid(tf.matmul(xs_t, Wz) + tf.matmul(hs_t, Wz) + bz)
# # perform the r gate calculation
# rt = tf.sigmoid(tf.matmul(xs_t, Wr) + tf.matmul(hs_t, Wr) + br)
# # perform the hidden state calculation
# htilda_t = tf.tanh(tf.matmul(xs_t, Uh) + tf.matmul(tf.multiply(rt,hs_t), Wh) + bh)
# hs_t = tf.multiply((1 - zt), hs_t) + tf.multiply(zt, htilda_t)
# # perform the ouput calculation
# ys_t = tf.matmul(hs_t, Vy) + by
# # add the predicted character to the output list
# ys.append(ys_t)
# ```
#
# A bit more involved now, but we've added the ability for our Recurrent Neural Network to handle longer term dependencies in the data.

# %%
# set up the place holders for our computational graph
inputs = tf.placeholder(shape=[None, vocab_size], dtype=tf.float32, name='input')
targets = tf.placeholder(shape=[None, vocab_size], dtype=tf.float32, name='targets')
init_state = tf.placeholder(shape=[1, hidden_size], dtype=tf.float32, name='state')

# create an initializer to init our weight matricies
init = tf.random_normal_initializer(stddev=0.1)

# %%
# set up our recurrent neural network and define the functions
with tf.variable_scope("GRU") as scope:
    # hidden state at time t 
    hs_t = init_state
    # list for output character predictions
    ys = []
    for t, xs_t in enumerate(tf.split(inputs, seq_length, axis=0)):
        if t > 0: scope.reuse_variables()
            
        # weight from input to hidden for z gate
        Uz = tf.get_variable("Uz", [vocab_size, hidden_size], initializer=init)
        # weight from hidden to hidden for z gate
        Wz = tf.get_variable("Wz", [hidden_size, hidden_size], initializer=init)
        # bias for the z gate calculation
        bz = tf.get_variable("bz", [hidden_size], initializer=init)
        
        # weight from input to hidden for r gate
        Ur = tf.get_variable("Ur", [vocab_size, hidden_size], initializer=init)
        # weight from hidden to hidden for r gate
        Wr = tf.get_variable("Wr", [hidden_size, hidden_size], initializer=init)
        # bias for the r gate calculation
        br = tf.get_variable("br", [hidden_size], initializer=init)
        
        # weight from input to hidden
        Uh = tf.get_variable("Uh", [vocab_size, hidden_size], initializer=init)
        
        # recurrent weight matrix, hidden 2 hidden
        Wh = tf.get_variable("Wh", [hidden_size, hidden_size], initializer=init)
        # bias for hidden matrix
        bh = tf.get_variable("bh", [hidden_size], initializer=init)
        
        # output weight matrix
        Vy = tf.get_variable("Vy", [hidden_size, vocab_size], initializer=init)
        # bias for output matrix
        by = tf.get_variable("by", [vocab_size], initializer=init)
        
        # perform the z gate calculation
        zt = tf.sigmoid(tf.matmul(xs_t, Uz) + tf.matmul(hs_t, Wz) + bz)
        # perform the r gate calculation
        rt = tf.sigmoid(tf.matmul(xs_t, Ur) + tf.matmul(hs_t, Wr) + br)
        # perform the hidden state calculation
        htilda_t = tf.tanh(tf.matmul(xs_t, Uh) + tf.matmul(tf.multiply(rt, hs_t), Wh) + bh)
        hs_t = tf.multiply((1 - zt), hs_t) + tf.multiply(zt, htilda_t)
        # perform the ouput calculation
        ys_t = tf.matmul(hs_t, Vy) + by
        # add the predicted character to the output list
        ys.append(ys_t)

# %%
# need to keep track of our hidden states
h_0 = hs_t
# apply the softmax output to the last output of our list
output_softmax = tf.nn.softmax(ys[-1])

# get all of the output characters together
outputs = tf.concat(ys, axis=0)
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=targets, logits=outputs))

# optimization algorithm
optimizer = tf.train.AdamOptimizer(learning_rate=0.0005)
grads = optimizer.compute_gradients(loss)

# clip the gradients
grad_clipping = tf.constant(5.0, name='grad_clipping')
clipped_grads = []
for grad, var in grads:
    clipped_grad = tf.clip_by_value(grad, -grad_clipping, grad_clipping)
    clipped_grads.append((clipped_grad, var))
    
# update the weights with gradient descent
updates = optimizer.apply_gradients(clipped_grads)

# %%
# now that all the functions are set up we can run this thing

# function to one hot encode the characters
def one_hot(v):
    return np.eye(vocab_size)[v]

# Session
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

# Initial values
n, p = 0, 0
#hprev_val = np.zeros([1, hidden_size])

for _ in range(epochs):
    for chunk in range(0, len(shakes) // seq_length, seq_length):
        # Initialize the hidden state to 0 at the beginning of each sequence
        h_t = np.zeros([1, hidden_size])

        # Prepare inputs
        input_vals  = [char2idx[ch] for ch in shakes[chunk:chunk + seq_length]]
        target_vals = [char2idx[ch] for ch in shakes[chunk + 1:chunk + seq_length + 1]]
        
        #print(shakes[chunk:chunk + seq_length])
        
        #print(input_vals, len(input_vals))
        #print(target_vals, len(target_vals))

        input_vals  = one_hot(input_vals)
        target_vals = one_hot(target_vals)
        
        #print(input_vals, input_vals.shape)
        #print(target_vals, target_vals.shape)       
        
        # run the tensorflow session
        h_t, loss_val, _ = sess.run([h_0, loss, updates],
                                    feed_dict={inputs: input_vals,
                                               targets: target_vals,
                                               init_state: h_t})
        if n % 1000 == 0:
            # Progress
            print('iter: %d, p: %d, loss: %f' % (n, p, loss_val))

            # Do sampling
            sample_length = 200
            start_ix = random.randint(0, len(shakes) - seq_length)
            sample_seq_ix = [char2idx[ch] for ch in shakes[start_ix:start_ix + seq_length]]
            idxs = []
            sample_prev_state_val = np.copy(h_t)

            for t in range(sample_length):
                sample_input_vals = one_hot(sample_seq_ix)
                sample_output_softmax_val, sample_prev_state_val = \
                    sess.run([output_softmax, h_0],
                             feed_dict={inputs: sample_input_vals, init_state: sample_prev_state_val})

                ix = np.random.choice(range(vocab_size), p=sample_output_softmax_val.ravel())
                idxs.append(ix)
                sample_seq_ix = sample_seq_ix[1:] + [ix]

            txt = ''.join(idx2char[ix] for ix in idxs)
            print('----\n %s \n----\n' % (txt,))

        p += seq_length
        n += 1
# Out:
# iter: 0, p: 0, loss: 4.167645
# ----
#  3&U3yoXpxYMlYZeY
# NP,WZxGCA!'D
# NB?ijujM$EVmUX&,P!CkKrxJZHAzXzfvcGGe'A,zMPA;QjknB3pXlkWHjqtt;PN-lcjG;lPncbRchPZKZ$3kPPSrZE'rdcrqoHwHpJ
# ,Htts,httedQtiyikQHEgLNeag&KYRrh-Xx .Or:
# kIDA$&OZnZmkiDVtycR$ReL3wc
# ----
#
# iter: 1000, p: 50000, loss: 1.468880
# ----
#  ERUCSgieuly yeur'beelt, perl se cisl,
# Hll, th
#  ile cr bu.c
# hh then tig lhan
# , on, Ptbhen ease
# Welt erlouat uo, wha. -a osy you a ntaven cathisheri
# WiTenely, bed myouusnnded whlm the
# sey, usdy
# Rentaln!
# ----
#
# iter: 2000, p: 100000, loss: 2.078329
# ----
#  d whulc me
# - loct hubl din they and wisit-
#
# First Cithzen:
# Hak nit werves 'g cuthoi; Voa jon?
# SgeErgithe torthee;ang, wir sheir wire.
# Wfmndther'd oo :or.
#
# MENENIUS:
#
# Firl? Whey'prel; fhat os whitW'e t
# ----
#
# iter: 3000, p: 150000, loss: 1.706717
# ----
#  Fhe come,, ar h to shell pat sourpd yourud sind ther haw form mominiusustade conosN fhe raln if arber.
#
# All:
# Fpreged y'l hin wimy,
# sink on the gitsprends desencl, ther, nothes shel meat shed and titiz
# ----
#
# iter: 4000, p: 200000, loss: 1.621351
# ----
#  lenss is is.
#
# VIRGILIA:
# And int his to is
# mo theicturestiel themelll.
#
# VALERIA:
# Io, it gerengtr sua th ure prale.
# H then an goendel, quith he peay hur whscoms. Vellk d'er muris;
# Team! keand liow, Mars
# ----
#
# iter: 5000, p: 250000, loss: 1.637238
# ----
#  wencone scoud?
# Nover senow ur: chanfed worther,
# With then th yel.
#
# MAREIUS:
# Weth, wouls mire he exvel.:
# Tie tikn to a awnes,
# Seat the peanle god
#
# te th ore-caneses'dy wall you are oveeftet,
# endick sun
# ----
#
# iter: 6000, p: 300000, loss: 1.312106
# ----
#  theas face,
# Thank ally good frith sr, nob
# Bepso Andeedt Uads, ffith, recenos; not part thimce bere chsels at inenether? Thith be of ort. What swe'l wing ab, to thell verab the riof
# OM thy whale belat
# ----
#
# iter: 7000, p: 350000, loss: 1.274765
# ----
#  .
# Whuch youls at arkners, which aid torfidids yout good olse stous
# Or laswers yougibs'tI do reackrdirld
# And crakntte:
# Weshith meresteess, more wirM
# RTIUup:
# I opeoll yours. Come, I moken
# Then seisg peo
# ----
#
# iter: 8000, p: 400000, loss: 0.707849
# ----
#  an word?
#
# VALURNIA:
# I wisl sham alland.
#
# VALERIA:
# In tay andaved is ains anes:
# ChRemblan tilushe with rowarforty Thowe.
#
# VILERIA:
# Goy ill.
#
# VAFCILIA:
# Be, ang thee outher wary
# Which mak ne the buine;
# w
# ----
#
# iter: 9000, p: 450000, loss: 0.964968
# ----
#  edert.
# Wo lrowe they'll on 's you. ' tare Marcius, thay heartcy ws chatring
# Becourdor mast hiss?
#
# CiFinsty:
# Ond ead, Coou, whele ha dous:
# Yeur cimener peour; and have toup. Have jy to at.
# Thet out sus
# ----
#
# iter: 10000, p: 500000, loss: 0.628506
# ----
#  wers afferth siod, to thet
# LEks t'erang thit gugstis benome, and fhe sutide btoones ave taris, their tayes,
# nour. What se,
# The shar btand, what upbrece abestol there in go surf im comv.
#
# MENENIUS:
# Nay
# ----
#
# iter: 11000, p: 550000, loss: 0.806675
# ----
#  he carmin; and char ith.
# Forst wera ono thither ond troono thather arsinn; Whethill diagitizine
# Whol's hen in the owe broon?
# First Senator:
# Of ie
# praike in mikn ine. We thare fir thit sare: af ghes?
# ----
#
# iter: 12000, p: 600000, loss: 0.639185
# ----
#   re upm: your loke atprentannthen wa
# k owy prople; I will hemer ghan how upmont, Mare' I hie done.
#
# First Citizen:
# Vell wy lup Ifllinglow If ale of good fod is;
# Or, Voll or a moone.
#
# VIRGILIA:
# I dapke
# ----
#
# iter: 13000, p: 650000, loss: 0.812135
# ----
#  rs, firtud
# unon everk! I rageed lyou hut Cain esuld, they sarfeed in.
#
# First Citizen:
# I wour manem, toul
#
# VIRGILIA:
# Noy, mote ppout: manes.
#
# First Citite:
#
# Velens yo' mo to the that ast natut, arim.
#
#
# ----
#
# iter: 14000, p: 700000, loss: 0.717772
# ----
#  n andies are
# That west where sin in the stare they ralle.
# Well'st ay the blyods ard, whllise hishes, mack me,
# Fout law ha nat noble Fir thr hem?
#
# FIrsteSelity, wo'dd meranct ate almore' they shall Mar
# ----
#
# iter: 15000, p: 750000, loss: 0.423680
# ----
#  but the surplis thyo shat they these wal th is come,
# wnt eremas A fice sur in thus salB, what's the watllom your hane consty.
#
# MARCIUS:
# Alves. Heal shele 'tte with ammerait; and all the roge, to madt,
# ----
#
# iter: 16000, p: 800000, loss: 0.553641
# ----
#  r farmadif aims! 'he commar, af whe erely, mare
# Whlle knde will be commonte!
#
# VIRGILIA:
# O, modded and fig
# Bofs: fog the doves,
# Bncoup will be comm nold:
# I doured bre your lanwerse.
#
# MARCIUS:
# I, thes i
# ----
#
# iter: 17000, p: 850000, loss: 0.549963
# ----
#  peg aems, lity. Auf dis be sovedy deedy us
# lisc'l bre
# 'sin: coubhich noo; but, you simy say. I will f thoog aowy prome.
#
# Tits coreads you. 'liang you blooks
# And, I belo thon k'wing nelay's tarea!
#
# VAL
# ----
#
# iter: 18000, p: 900000, loss: 0.387275
# ----
#   framprespouttrive' there camebleach abmer--couptrest, is he alfor?
# hither belowe serences for ham you hame.
# ham dse hither and you, aveey anmienke. That ank nout hush alverse my tor prome. Hes, and
# ----
#
# iter: 19000, p: 950000, loss: 0.314390
# ----
#  perofby comestentughis, must has, aclike tourshup.
#
# MARCIUS:
# Thay shat wiuld ur a anowhele had I gain,
# Yeat geas now she lity tho cirns
# Let heardo dim, mak, and ofr hius,
# Whan mo tulluy haid, whan sha
# ----
#
# iter: 20000, p: 1000000, loss: 0.356036
# ----
#  in, ay, has apet then of tils s' that
# well chumars an this mayt
# The wasme and nelor prace it is
# and husceadont farmy, dow ht mass
# as the rejush! To yo erterfin; hne st wather you shey sarse af on
# Thes
# ----
#
# iter: 21000, p: 1050000, loss: 0.226952
# ----
#   llabyer anown pay you his foot?
#
# MARsIUS:
# Whathis they seeds mest. 'giad my
# lomy: wat are
# Upone ma bur the rodes commpenieg.
#
# MARCIUS:
# I'de, benay s' leva aller trea
#
# Whene har shall fom ha camisin o
# ----
#
# iter: 22000, p: 1100000, loss: 0.259580
# ----
#  he cimils? 's am andind.
#
# VIRGILIA:
# Now you hemes, s
# feat speak in moll. It what weavess Fort la kere; and Yeur aberbe, by be pronly; ay?
#
# MENENIUS:
# Noy, my the diter; and yee sall thee will by
#
# MeRTI
# ----
#
# iter: 23000, p: 1150000, loss: 0.309558
# ----
#   sine our he cume notr, and flobrt I then mant of ammind.
#
# VIRGILIA:
# Now whow upon you your gandsry'st, chatreal,
# dif alushepend whow the perpored sor pity mike ondey
# For the chan ant on arming agoins
# ----
#
# iter: 24000, p: 1200000, loss: 0.212016
# ----
#  you so fitl shoure fandes from morice,
# Shel, preyear: it go dsward. Hechacl the owems ove out besese this aicines,
# Hell, busalfal turnter than
# Hak  as would you adlldy's.
#
# LARTIUS:
# Agly seld, I port,
# ----
#
# iter: 25000, p: 1250000, loss: 0.281799
# ----
#  a the fremeeave ham againtt,
# Aghins lake than wiy  anewew way s your offectablines.
#
# VALERIA:
# Comy, wark,
# Than leat to fall nepr ale rise lage in ormy knowill pear I uldore and ho ga. Tot wall: Roma!
#
# ----
#
# iter: 26000, p: 1300000, loss: 0.349986
# ----
#  oult ithied
# And on! To enemy, whot
# Uedner'es spaves fram, Mercius?
#
# All:
# Ala hur it is ain; I'll bell: chanset in up.
#
# LURUe
# So
# Fow towar canesctersidiust heas!
#
# AlfIRIAgminge; theys.
#
# First Citizen:
#
# ----
#
# iter: 27000, p: 1350000, loss: 0.244651
# ----
#  se food thyog aiming,
# Out lfees a showd from our bestyes.
# What stroed use though titt ruthes-dof I mange,
# The keat to the Capitol. I wark' is go a moper,
# Whole of etty the prove toun woupd corvar.t
# Vf
# ----
#
# iter: 28000, p: 1400000, loss: 0.258290
# ----
#  ot that jrethI redeed, and faglitszene's
#
# Sicsct yol-core. What you hore? come.
#
# VOLUMNIA:
# Away them-op, thot ingidiust I kear:
# toul-bout tallebst Rom we
# O veiththe hingr heew rsme that answer'd,
# And
# ----
#
# iter: 29000, p: 1450000, loss: 0.254339
# ----
#  or hear
# A sicl ha dignt enedo 'emad in ford betreat wish me sort: Our of yours.
#
# BRUTUS:
# Fio 'tr Ahe tlarte that against the right: nover.
# VOLUMNIA:
# Away ly wall fremute if the unor, ave stark
# ffies
# ----
#
# iter: 30000, p: 1500000, loss: 0.243786
# ----
#  ke at Tull, fie died
# fereang ave out foulhsow foe tire for shat homy? would and ee lat ms amsty
# Foltodr their liense sin theme falotrs, good modertelt, I wore you ho you that!
# To your ip tht one's for
# ----
#
# iter: 31000, p: 1550000, loss: 0.450209
# ----
#  yeur lust!
#
# First Citizen:
# I say unto you him ?r
# Rise these well, ghe rit done. Hewam sendigl
#
# Mersinger:
# They liss y u'licitirith.
#
# VIRGILIA:
# No, at a vont, mase a dour, live thome helove tion.
#
# LeRT
# ----
#
# iter: 32000, p: 1600000, loss: 0.178786
# ----
#   thes onattlo. 'emancersws's, and thes asmink.
# Will you in the blind a
# cinte of giest to the
# Coiss
# Cooundry their cively sont: but I lo you, atlledon
# Is ace ie han stinns we's, goad from tor
# What's th
# ----
#
# iter: 33000, p: 1650000, loss: 0.167993
# ----
#   rimowe
# What hurs of Rome whese had at onrrackn on whet you had shaves badas:
# Buttores ale heart, they oell preadite benewh gate,
# What shat s'ems ave nat, Cominius.
#
# BAUTUS:
# Ceme te anching on this sa
# ----
#
# iter: 34000, p: 1700000, loss: 0.267587
# ----
#  eit, you'll yes of Mens es. chat wo know' dowbe comes: and of at! Thuy, larkitigu? shele 't. ruther way ho fiten, you shatl, wish
# me pact cim brobei
# sFirst Seeith,
# Yould re hat he makest to fattir'?
#
#
# ----
#
# iter: 35000, p: 1750000, loss: 0.190789
# ----
#  d
# Your vary dave hain the gods from herrice the engrives; let you hewervere; he chyel, no
#
# MENENIUS:
# Firss careast.
#
# First Citizen:
# Whill vistr. Wuthes you spofd its chois, wirs my the perinens; I pik
# ----
#
# iter: 36000, p: 1800000, loss: 0.228829
# ----
#  y hasen their caves, thither the poons: chunff heme? speake bulikis  ageangr andity, I'l-
#
# First Senator:
# Your counseas bat mank you proud. I seall their cumme? shim ,
# Your stow bestee and chan this s
# ----
#
# iter: 37000, p: 1850000, loss: 0.419269
# ----
#  ll good in;
# rele: hamb telo gtherethe remesh mone ondo gaidsc,
# He wialdobe fortheit ole
# Thaig ciun on you! from, Merciud.
#
# First Senator:
# For what at way, blioks
# To beer't heree that jeetaI'st ingter:
# ----
#
# iter: 38000, p: 1900000, loss: 0.108747
# ----
#  ag, endy your gone arens?
#
# SeCono gond by dievin bo
#
# BRUTUS:
# Te and untiret you humfeat out
# of icoubho heswers and I'd-h
# 'low tees your gieds to tow
# Of I huspeake butite in army be; I payterol
#
# ARCIUS
# ----
#
# iter: 39000, p: 1950000, loss: 0.121945
# ----
#  -iod they of deirtn, the fither stond foleswers ghatred we in have pary.
#
# MENENIUS:
# I well you. chies
# wo hemen browe
#
# Verseever: high in; and afmo.
#
# MARCIUS:
# Sece har he minith, you mays evens on. ghi
# ----
#
# iter: 40000, p: 2000000, loss: 0.140174
# ----
#  in stwing and clust, Thece pire on Rom: and whas all half giad ngon 's good
# plack eis tane fatlyos! 'lis go. Seir, whe comes leve ht
# rnees
# Undin the supersle; and
# Comiells. I' lur than ffims. They als
# ----
#
# iter: 41000, p: 2050000, loss: 0.797542
# ----
#   bear then thy lenter dsems:
# Noon us then fow e preases d pits,
# Whan shopes are un aodt grove great wo the hisser
# 'thin-!
#
# All:
# Forewell.
#
# All:
# Fareweeld the powrsc
# whin
# sonkidity couftilf cammand.
#
# M
# ----
#
# iter: 42000, p: 2100000, loss: 0.153600
# ----
#  T sanswaf thon
# sheses are and I'll the bodle tar then?
#
# VOLUMNIA:
# She that if alsowa cemband
# ht hereant hefewe pry ait now preafe.
#
# First Senator:
# Farewell.
#
# SlCENIUS:
# With gueare hes ding
# nother man
# ----
#
# iter: 43000, p: 2150000, loss: 0.140798
# ----
#  ome or hos sctmelte will th, bruld hear gotd, they nows neword, I'll keed you. canter's are ally
# Tour prothe carign an way! 'oun upen hat me whore hone mest cinns?
#
# BRUTUS:
# Come,
# Ha thaic be now I sma
# ----
#
# iter: 44000, p: 2200000, loss: 0.097036
# ----
#   coumop, fiol!
#
# MENENIUS:
# Nay, thes' are you seany the r'dine state, wh.
#
# MARCIUS:
# We the revervar
# Agfear nowiss and eveir than this?
#
# MENENIUS:
# For that, beent ane faims? What has Voleceantee dear hu
# ----
#
# iter: 45000, p: 2250000, loss: 0.094211
# ----
#
# MARCIUS:
# Hing dem dasm them ?o
# The well I' laky hashe htirne theie blankes us alde thal whe ain;
# Yruching twether then of doule that washar's for h madam, harr geee
#
# First Sontior: bo bayso,
# I wish w
# ----
#
# iter: 46000, p: 2300000, loss: 0.303921
# ----
#  lRonst Coinsor
# Auf you. Whit is neple Aafed of my parties;
# Alpitit to mon
# OViLERIA:
# Wher, hear it witl com on aif. Sut, fard hears, the but
# Firster, bo rechar.
#
# VALERIA:
# How dors.
#
# VALERIA:
# Come, lagk
# ----
#
# iter: 47000, p: 2350000, loss: 0.091641
# ----
#  e I'l o' the goed ald thes ofr: in ore. They ne shum s then why wast, whet you.
#
# First Solvier:
# Nor Is.
#
# MARCIUS:
# So, that frem
# we Latk but the Rofe: not upin the doust,
# That le vient he mad on you. W
# ----
#
# iter: 48000, p: 2400000, loss: 0.053079
# ----
#  eather fins ruetor. Thay our, and the oncay partiYou,
# And fit th t with betone thaib now, end your lupobeto, fard, bus, mark mi,e horset, but follo tofe.
#
# MARCIUS:
# AFayes.
#
# MARTIUS:
# Thay proveste, the
# ----
#
# iter: 49000, p: 2450000, loss: 0.118721
# ----
#  rch, the fallonst'elf you. What shall Mere city
# is wiser that ont to muep on, I'll thay a ligriend
# MemCinit sortenomy, comand,
# Ot heil country then yout nough a corelier, Au
# When the doust, the prain
# ----
#
# iter: 50000, p: 2500000, loss: 0.087821
# ----
#  or, is a formest to ewers Of me eversa perite
# This elled
# and fee ham in haif the buprem ene
# Thet leapyor' lag enthtmen seall heme lee mar, I whan well ofe
# the one softel's feels so well beld: mutum.
#
#
# ----
#
# iter: 51000, p: 2550000, loss: 0.581514
# ----
#  se mot notst if faies, good sadeed,
# Our alJing. Wo hid reelly,
# And lick I hear, gotstrang or a for he.
#
# AUS:
# For have him good
# spink 's your son.
# I ste stale--how what Ifrne firhth the seep,
# And kive
# ----
#
# iter: 52000, p: 2600000, loss: 0.175321
# ----
#
# MARCIUS:
# Give me porte.
#
# Second Citizen:
# Nay, ghes with rust chan
# To kind thour gavesal cire re citer, lorcime, in tond poor thy henpees
# To an partieilust Coin so kenw their counsels en.
#
# TIRIA:
# What
# ----
#
# iter: 53000, p: 2650000, loss: 0.040090
# ----
#  ld your theich if heart.
#
# VIRGILIA:
# O, good madam, there can be non un kone though hind chonge compace.
#
# Ge,tleorilicus,
# An whel be one Cimin us rema this brateds,
# The gleat tog.
# That is thule so'dla
# ----
#
# iter: 54000, p: 2700000, loss: 0.114613
# ----
#   me the revertartir betoufir us not, every how ther?
#
# VOLUMNIA:
# Hey hand 'efrat enerely, madam?
#
# VILGILIA:
# His oro sablind ts upon shien, you dissertirs.
#
# VOLUMNIA:
# He hade the wars, have you, emong h
# ----
#
# iter: 55000, p: 2750000, loss: 0.449099
# ----
#  d anl figlt or ber basesh prituneds on aif. mutt rush allyear
# Has ol RCIUS:
# For holle stritee you ribenkind hird be on comet ffom hare.
#
# CIRGILIA:
# No, I smo ond el.
#
# First Citizen:
# Yo' mo tord, bat ma
# ----
#
# iter: 56000, p: 2800000, loss: 0.170643
# ----
#  he pats, in they ours affoutay whowe wall they why, why sway the store.
# They alver make htha glow mose counter Camirous. Thiu ds'll hied mese wars of May aum
# Hel suall you we proveed and fakes; would
# ----
#
# iter: 57000, p: 2850000, loss: 0.104005
# ----
#   luve ave they whire hil stewn.
#
# LARTIUw:
# No, I llay your flion;
# They's pretone seremble Aude: a dy cotnortaycu.
# When sho disecaus epance; the sulped well bunter freis,
# An they agling the fonle: on R'
# ----
#
# iter: 58000, p: 2900000, loss: 0.041543
# ----
#  l on you, good madam; I pray, they wirhay your ities we the belly
# Am Hece his ange cour, ald enceribs
#
# MENENIUS:
# What work's asmy Voly: and fagrithid, you than then?
#
# VOLUMNIA:
# Then hivl be ow Cominiu
# ----
#
# iter: 59000, p: 2950000, loss: 0.484166
# ----
#  for touthers, thoull indee,
# Tne on west vainis; and feallo sad fead ht.
# I was they whis meas a cinear
# Buitifene footh. Tutul farthe melpea non the fiel shey shy you peithile; I will obe or you:
# For th
# ----
#
# iter: 60000, p: 3000000, loss: 0.143548
# ----
#  That meat rush an would, you mast your huts,
# The halfse hold then why way se for hall one go diddreciup?
#
# VOLUMNIA:
# She shall, she shall.
#
# VIRGILIA:
# Hid dis caus; I's ank no the for that mist ence han
# ----
#
# iter: 61000, p: 3050000, loss: 0.082670
# ----
#  nd veel the come in well,
# And a mus ofrt up,
# You und of the viou?
#
# First Citizen:
# I say unto you hear, took parties strous
# Sefll IA: ace one soue baly, which he great toe! firgul.
#
# MARCIUS:
# Hang 'em s
# ----
#
# iter: 62000, p: 3100000, loss: 0.105076
# ----
#  , Marcius!
#
# AlsCINIUS:
# Wer, mortulf out of met cousarewith mera and
# If ain ankering hat he ineervere; he leve comm nato.
#
# SICINIUS:
# What were for hor aspetht piopallinissalf the beay thon prayk moke p
# ----
#
# iter: 63000, p: 3150000, loss: 0.087996
# ----
#  he madysd sho'd taun'd s ffrm eave you shall nof.
# lure tog
# think say an werthe themer bester make homou.
#
# SICIrIUS:
# Betile, ar you  hith rome petoue wills, that you miRecoup till mut uran forthyous us
# ----
#
# iter: 64000, p: 3200000, loss: 0.077351
# ----
#  ehey lady, ir, s,'t out.
# To enows you ort to ensigeling; a cormorant geiver
# Whoce make to guea tlogett and alus?
#
# MARCIUS:
# Then he were head than thy lensers.
#
# VALERIA:
# Now at low Seeithore--
#
# First C
# ----
#
# iter: 65000, p: 3250000, loss: 0.222200
# ----
#  oo that with oirt mo in thes we heal ce. but, en you groness of
# He poot forthy prouf by opeared wo peaty. briok's apesse:
# Hout wow 'se farmet for the Cominiust,'Thas ealle uprais dogeth.
#
# MENENIUS:
# He
# ----
#
# iter: 66000, p: 3300000, loss: 0.055712
# ----
#  ood madamy surHe,
# wot made resert, to, he dear the bbleck dis caust?
#
# filst: how mo?
#
# First Citizen:
# If I must not, I need not be barreain;
# She blayethus before mo thetreak the belly answer?
#
# MENENIUS
# ----
#
# iter: 67000, p: 3350000, loss: 0.040883
# ----
#  or hyou hut than thus:
# Fakewell, what then?
#
# First Citizen:
# Should by the firet of hings' your soffemine corrseat, The volleragatns, they you to nop out you; fareshold.
#
# VOLUMNIA:
# She shall, she s'll
# ----
#
# iter: 68000, p: 3400000, loss: 0.088813
# ----
#  el ing no humpeake dour daswacl.
#
# VALERIA:
# Nore me hara; they, A like to sinw rathured in whice abmy s.o
# d, ar Hee ar hame hear chan
# He farbmo him io thirgh evere and enough with u'st Cari; I poryon.
#
# ----
#
# iter: 69000, p: 3450000, loss: 0.369080
# ----
#  pout to the reveitins whelds that afle: affratay; buld, mara,
# Whan shoves's ale the mutt Your wasle. Whith our spouf me sorames you blood ther may's afewers, murt.
#
# First Citizen:
# I the hrnathty thoth
# ----
#
# iter: 70000, p: 3500000, loss: 0.129363
# ----
#  eckeratado bow whene's Lentubully, with teesiel,
# Ard you have for my to the pancens.
#
# BRUTUS:
# Farewall Comitius, the villidit our fall; and
# Your huprebloved than seethelr. Samus, that againstous relom
# ----
#
# iter: 71000, p: 3550000, loss: 0.113046
# ----
#   a tider citifer their counsel nor baty.
#
# First Citizen:
# What then?
# 'Fore me, this fellow speaks! What most what sheews
# Theyon encousher the brense sord: if their good
# :
# Frey dems, that against the no
# ----
#
# iter: 72000, p: 3600000, loss: 0.070128
# ----
#  hot wors wholespoke wish beishell hemeady rubu,
# Lik flibein giod him foult
# To f wilh or tofraglinoun the ghas eelirs. I pake ther we hat sell you
# A preceis Uoust whis foultir's ustelf wes and poot; on
# ----
#
# iter: 73000, p: 3650000, loss: 0.080689
# ----
#   cames for the remee?
#
# First Citizen:
# It was an onficly
# Whe here fou to the peaple my sarkifet whim Letle--poop
# Whend rave but envaind than seethat I smey har it our of Rome are this grod
# we hear hear
# ----
#
# iter: 74000, p: 3700000, loss: 0.182250
# ----
#  punere; well, well, then the revenkea
# Whe sers ass of your apmond.
#
# SICINIUS:
# Thenows were thesinids me; and the gots,
# Lety ut aftotnobs.
#
# VIRGILIA:
# No, good madam, prewes!
#
# VIRGILIA:
# No, as are fit
# t
# ----
#
# iter: 75000, p: 3750000, loss: 0.094154
# ----
#   in the mitin's,
# Whot seaves all the belly, thus acks wa brty.
#
# First Senator:
# So, your opinion is, Aufidius,
# That wewer 'sme he our downs as well, then when
# who eese that wak you wiml ir their likn,
#
# ----
#
# iter: 76000, p: 3800000, loss: 0.117247
# ----
#  g siftel when
# If you mor man so feal, act eeservom. fot you!
#
# AUFIDIUS:
# And kele asme.
#
# First Citizen:
# Well, sher's sooked you huslels af ats
# To the Camis lover whan bendes the ghas enke what the it
# B
# ----
#
# iter: 77000, p: 3850000, loss: 0.060600
# ----
#   risur,
# The frien sha lewe that when
# waks and have but's arithe rselp,
# And leve black dis betondot yew.
# Whether fremeat hir Ipanes; What's the matter, you dissentincas
# prould reether
# Phis I pitizen,
# S
# ----
#
# iter: 78000, p: 3900000, loss: 0.082907
# ----
#  r the luspet.
#
# VALERIA:
# In earnest, ha' lfor m spurtelu he fire so prtueed fom and tourts ro hevriendy that we s'ts beibl bried and that I wink ou to'd: come fearied sin; on king him; or the gods ande
# ----
#
# iter: 79000, p: 3950000, loss: 0.333282
# ----
#  cheas, and your Marcius,
# 'th seepo: the brain; and in henge; where hangere, wish your halfirs.
# Yo kurd butrRIUS:
# Fir the revertug.
#
# First Senator:
# Farewell.
#
# All:
# Farewell.
#
# VOLUMNIA:
# Let har aline wi
# ----
#
# iter: 80000, p: 4000000, loss: 0.093174
# ----
#  af it hin now paich if hiswnech;
# You, now your hinger you husheak the breis aru nstrtain; our saffrrancus I'll senator parewsid
# so, did me as momis ame feam rubhing she shall pont thenr
# cown rable spe
# ----
#
# iter: 81000, p: 4050000, loss: 0.078086
# ----
#  :
# he heaver that fels worse art mesus.
#
# First Citizen:
# I say unto you
# Aufingly whomes al were what we
# k onk makesm shall pele
# And kiev dean couffellad-Rome mare as you.
#
# VIRGILIA:
# No, I's anle feer a
# ----
#
# iter: 82000, p: 4100000, loss: 0.071651
# ----
#  our?
#
# Second Citizen:
# Wort, the great to the senk o' the city
# is risen: why stay we prating by the diel.
#
# MARCIUS:
# For that, angarno than sake the serpoabsty fare, be
# in, ee dody though seeld st: not
# ----
#
# iter: 83000, p: 4150000, loss: 0.075754
# ----
#  of the beirn acu. Nor your whoth,'lWi' desey pat in thirst for repeys.
#
# VIRGILIA:
# No, at are in and in what fashion,
# More than his singularity, he did it to
# pleame howouch afe to visea that fasmied.
#
#
# ----
#
# iter: 84000, p: 4200000, loss: 0.258834
# ----
#  rtten.
#
# VOLUMNIA:
# Wher, you may me absore,
# That 'e and feight with well vere har kien wor.
# I And in ir son: in joy stou; was r bare.
#
# VALERIA:
# No, your bood
# Haccius dee cemel in hime Will in arsmone s
# ----
#
# iter: 85000, p: 4250000, loss: 0.067582
# ----
#  The Volsces are in arms.
#
# MARCIUS:
# They have are their viny here? sun follow!
#
#
# ARCIUS:
# The om your it, sir; and yours lffesta With hem. I will with but find
# I hray your stiff be womprabenders if the
# ----
#
# iter: 86000, p: 4300000, loss: 0.059808
# ----
#  tin.
# Shay surComin us remel nrough. Wo dar afath.
#
# MARTIUS:
# O, the carns. you pried.
#
# VALERIA:
# In tagnat; and allo the gods, keep you in awe, which else
# Would fird for you wion one own thought on in c
# ----
#
# iter: 87000, p: 4350000, loss: 0.126840
# ----
#
# She cours, that them fordease, thon shald
# 't has dieesing, I
# shiel seeing he rim stand' that af
# Thal ue the geneoales madam; I will not out of doors.
#
# VALERIA:
# Nob an wors. Comemos, to gue Volsce, th
# ----
#
# iter: 88000, p: 4400000, loss: 0.078419
# ----
#  s,'Tes; ever be
# ans The one their liky a oul great toen to your fanger feers mveis
# Marcins hare I hure in hema known preyom.
#
# MENENIUS:
# I wis ane theie sworde that wastraigs must this eply sat;
# The Vo
# ----
#
# iter: 89000, p: 4450000, loss: 0.487008
# ----
#  ce rechied the gods, kees ark sey s.
#
# First Sontior:
# No, I prock,
# You hurse tagling you him northy shatchire.
#
# VOLUMNIA:
# Then, le, whith hemares madem ht.
# What surpe Aur parus, I shall betith, beich m
# ----
#
# iter: 90000, p: 4500000, loss: 0.049367
# ----
#  ithien'd, modem.
# utsar that laty: inseever ; and I know now fer aift in hemest notts!
#
# First Citizen:
# I the great toe! why hang harg 'e,
# in would and the go prouied
# With you lich nor list your hate;
# ----
#
# iter: 91000, p: 4550000, loss: 0.026215
# ----
#   vily thim ulan to the storn, the valy the lender with o known
# Of the wird if hearth, what atlies
# US:
# For the deart, in this? quard yours?
#
# First Citizen:
# We han lt gies of the soode: you prond knog b
# ----
#
# iter: 92000, p: 4600000, loss: 0.067376
# ----
#  ck it hive.
#
# MENENIUS:
# There was a time when agl the deary, mose thain good sadse, they, you ane on ofme to huspaknod.
#
# MARCIUS:
# Thends leve rebreatend, I they yaugh our on.
#
# SICNIUS:
# Noy the wrome an
# ----
#
# iter: 93000, p: 4650000, loss: 0.109883
# ----
#  corn at our own our pauts, thes your forto budithe .i
#
# VILENIUS:
# 'Thoud belleds an whole homes ale on 's fatlest,
# And head more an great the ghove
# Buine sho'd bessever than stite he with yout to eace
# ----
#
# iter: 94000, p: 4700000, loss: 0.002549
# ----
#  rubher.
#
# First Citizen:
# Nark le man briod seild on on your wants,
# Your suffering in this deartly tore
# ard and him; he mitht Le't glavent have sunod. Come; I would your common
# 'dir sankeds, I mo ghat t
# ----
#
# iter: 95000, p: 4750000, loss: 0.577020
# ----
#   use showe walls west what whes
# your lake hought first fol; whese ing
# jeithter.
# Which the mants,
# Your vastrong anm them; levaict whon; gods
# Upon thishe Camigubly canapof.
#
# fics cuy broy for the poorth
# ----
#
# iter: 96000, p: 4800000, loss: 0.084931
# ----
#  nd change 'smast, you ands yourselves?
#
# First Senator:
# Noble Aufidius,
# Of they word: and presume soufud urtour bldoves
# Brang like his nacking a
# mareim; and again; on goan pryou; for enamy, bood
# swers
# ----
#
# iter: 97000, p: 4850000, loss: 0.108140
# ----
#  al ang thus stincl.
#
# MARCIUS:
# I'll bey him sheer comelan one great recines in th is a
# moon it joul take and penkies.
#
# VIRGILIA:
# I will wish her ste dould betrevad unous aceies
# Beten the helf he citef
# ----
#
# iter: 98000, p: 4900000, loss: 0.103111
# ----
#  IUS:
# No, What mast have cine them Plued allond sing velius.
#
# VIRGILIA:
# I will wish her speedy stren-er
# And ceap o brtieed us.
#
# TIUMNIUGming, I sholl, I speak flo: a pinctore-
#
# First Citizen:
# Well, sir
# ----
#
# iter: 99000, p: 4950000, loss: 0.093244
# ----
#   spolico luck must hero gonce pire in rance; where ha gatnerse,
# She plapue up aties and pfors war my it
# As ton our minechisste whore powe they beir, andy those are account.
#
# First Senator:
# Nable Aufid
# ----
#
# iter: 100000, p: 5000000, loss: 0.103171
# ----
#  o surer, no rem nat ub,
# The breyst followed! What do knepwyer shold pont h' the Cain, tare you.
# Farewell him ane thong lirt. Whet arm he an wion I hear the gheat to know' tow where coup
# tork well o' t
# ----
#
# iter: 101000, p: 5050000, loss: 0.052034
# ----
#  dis icus,
# wh, it the forl ha bed whel re hiver that he paysu' touts,
# That in these servag his prtplake.
#
# Sicon sCof accusa, tood stace, andse caramant
# Senown what senvard ig asmy toother.
# With ave arm
# ----
#
# iter: 102000, p: 5100000, loss: 0.077966
# ----
#  peitibute, when us you selly--rougt aim; which he ist enee.
#
# VALERIA:
# In truth, la, go well, spor, is,?
#
# First Citizen:
# I the great toe! why ardyshis; merites
# Of may be on ouf ur mpeace not sprat they
# ----
#
# iter: 103000, p: 5150000, loss: 0.059065
# ----
#  he veilides.
#
# First Citizen:
# I the great toe! why say shall four faroroles ever it.
#
# MENENIUS:
# Nor madam; o thur, bearne thou sttees, d abred in.
# They dear the revertartine and afces way arit.
#
# MENENI
# ----
#
# iter: 104000, p: 5200000, loss: 0.202894
# ----
#  ercaingr'ten and his ors thems?
#
# First Senator:
# Our army's of we that
# If a mall. For that stands ampetwould.
# Wo ther esem the fliers at the vely armiee.
#
# MARCIUS:
# I'de lene he ser min:
# Yeprete turong
# ----
#
# iter: 105000, p: 5250000, loss: 0.100307
# ----
#   the great roch pearued.
#
# VALERIA:
# Noy art belo! 'tragain humberd and there are allost Rome
# Should know the geas ans ewell.
#
# Slcone Citizen:
# Wortimf y umbet ondeed.
#
# First Citizen:
# Ye're long about it
# ----
#
# iter: 106000, p: 5300000, loss: 0.086235
# ----
#  s. He that hewerd make and go's daultt fore! To guad Citizen:
# Core for hil patstem he, well, bell'd hads, fird my sort, they ladaug
# Our good wall sitcr be with you; and wo'l! Tie dageth hath genvers.
#
# ----
#
# iter: 107000, p: 5350000, loss: 0.061086
# ----
#  s nothing. Whisd meyencour like halfion chance waf with trood. I seell whel be the latrecions you.
#
# Fisst Citizen:
# We cannst the ruthan whal seat comlory tor hes
# Brum, ' than well, where the other ins
# ----
#
# iter: 108000, p: 5400000, loss: 0.092736
# ----
#  l bele: but fall. I spll vanting.
#
# MENENIUS:
# 'Though all at once cannot
# See what I want love.
#
# VALERIA:
# O' made ho, goaden.
#
# VALERIA:
# An carnd than con
# They leas the sadr cames frighteends you memind
# ----
#
# iter: 109000, p: 5450000, loss: 0.065354
# ----
#  nd he dray poor sure, and thes afmy, and when he lets and ele
# ReA:
# He hade feat first Cotizen:
# Let us wers atnest our affections are
#
# thene our d gors of Rome ware your latreains hive for you prouf, a
# ----
#
# iter: 110000, p: 5500000, loss: 0.798112
# ----
#  itile in hempea would hear
# A pear, me,
# Or heve your lloye ame out so vagcayethis; my eave aris curstithas'lqint; not und for the foight yours lavem mind rs out gelver-t
#
# Teson: Citizen:
# Concity the go
# ----
#
# iter: 111000, p: 5550000, loss: 0.081846
# ----
#  se ves are in arms.
#
# MARCIUS:
# They have are soned prewies and placumer'd tnough your spiak makess pore in they
# whuth allattsely hame in here hear then se you spenkert go sturs,
# fir unoccance the ition
# ----
#
# iter: 112000, p: 5600000, loss: 0.090107
# ----
#  are in answerverour
# blick do bellmen sigh whuld and the shapes of men,
# hewhad st in makes: mank ye! Telond leven.
#
# First Citizen:
# Fars; lus manks forth betine it with
# 'een our geave to the ment? 's wi
# ----
#
# iter: 113000, p: 5650000, loss: 0.075397
# ----
#   ar hend rsmien the helf do dof your hate; and gnaputs, mellants,
# Your veeth. I she like to blo king boon my burs.
#
# VARENIA:
# Noy, beland the bray,'s of weeperimented the geestale to a
# maneshelivest th
# ----
#
# iter: 114000, p: 5700000, loss: 0.112227
# ----
#  n this alastiog.
#
# VIRGILIA:
# I thank your ladyst ont entardis,
# What sably 'sir not Come follows proud as is this Marcius?
#
# BRUTUS:
# He whal ou have leave bs a fore faroust,
# What sably Marcius;
# Ithe go'd
# ----
#
# iter: 115000, p: 5750000, loss: 0.072773
# ----
#  bot stame on his bont greas no the genstal' dose: pareimi; while hill well wher me, To and Comu! Mersmice.
# Whet are firsh are to tinery, I shy the fayour offecturep,
# Aud you him llan enorshes. Camus b
# ----
#
# iter: 116000, p: 5800000, loss: 0.842532
# ----
#  ow rove whom then?
# Thou hus as 's pantinf.
# Btions aretay's:
# Welawathsabst the thours are stome,
# Your strus, and my us noong you what servic; shoth, the padsing answer'd seaves, must heve parous my; br
# ----
#
# iter: 117000, p: 5850000, loss: 0.111635
# ----
#  ar but fell the body, not if
# theyswering
# ho heve the wars dow he citsten with reatire sin thought on in thim strtade's partily say?
#
# VIRGILIA:
# I thank your ladyst spow thess prothes, grow we proceed.
#
# ----
#
# iter: 118000, p: 5900000, loss: 0.093058
# ----
#  dis mede here; you shall fontore to luck.
#
# VALERIA:
# In earnest, it's;
# an well, then you, lave faurthis bratce whene allies of yours?
#
# First Citizen:
# We cannot, sir'd Mereicu enemy,
# What sholy selp div
# ----
#
# iter: 119000, p: 5950000, loss: 0.040999
# ----
#   himes of deer,
# Ore where foxems to him s' mitt 'sin, foo thuthat in there feel seall speak.
#
# VOLUMNIA:
# She sea though ehungan
# Marcius,
# Atheng hem aithol. I smy though and eles?
#
# Auf,--See hill be not
# ----
#
# iter: 120000, p: 6000000, loss: 0.003571
# ----
#  humban the groat worth in eepey this gheats, made howe frumiog.
#
# All:
# To the lome it now partie dongula
# cunes the ont thom paltiel.
#
# MENENIUS:
# Why, master hearing
# Lete vartus; and agme to farisith the
# ----
#
# iter: 121000, p: 6050000, loss: 0.095834
# ----
#  ing brous it for y areway Whindspeet not ur not, and all him fall endoud bedly--otiee
# Butibudenerse than were shold pincurspetiof alf acmoo!
#
# SICINIUS:
# When we were chosen tribe with o out ratue.
#
# Fir
# ----
#
# iter: 122000, p: 6100000, loss: 0.064323
# ----
#  on. I' the good los If a more.
#
# VOLUMNIA:
# She shall, she shall.
#
# MENENIUS:
# Ho, I leave for his tume
# Son, I'de reteet the gons are set do sect. A mateer, you disenous the shapeid
#
# First Senator:
# Our ar
# ----
#
# iter: 123000, p: 6150000, loss: 0.191653
# ----
#  ,
# I well you, do thing our uf.
#
# VILIRIA:
# Well, there ave nor goed
# Upenithe wars gits on when
# 'O, are all in erumb,'s for he'd prove
# Butter, and Camus Marcius?
#
# All:
# Against him first: he's a vind
# Now
# ----
#
# iter: 124000, p: 6200000, loss: 0.079148
# ----
#   the rerevaint hive for make ethour deangh swers.
#
# VOLUMNIA:
# She shall, she shall.
#
# First Citizen:
# We hal strone stand folly feret firsters, the ruthris,
# Mare Vhar us not, I they whal than then?
#
# Firs
# ----
#
# iter: 125000, p: 6250000, loss: 0.057355
# ----
#   half a candonce; I.
#
# Sucs in head cornout firles,'s that beht leven.
#
# First Citizen:
# You dogrt your listit.
#
# First Citizen:
# First, you what we hat hang he
# The miot, I wall
# With gitis good forth their
# ----
#
# iter: 126000, p: 6300000, loss: 0.101813
# ----
#  e crumbees, my good, cime.
#
# VOLUMNIA:
# Indeed, you shall not.
# Methinks I see him stampst the Volsces have myon powed for that
# They are not such as you. Junis; Yet, ghad theng lers.
#
# VARGILIA:
# He had sa
# ----
#
# iter: 127000, p: 6350000, loss: 0.065093
# ----
#  henres,
# Or bein up fill your hates he pars,
# Let, and the only south list, what work he makes
# Amongst your clove
# Hean the Capitol; who's like to rise,
# What sare they ol you do may an you wive yet: the
# ----
#
# iter: 128000, p: 6400000, loss: 0.072197
# ----
#  mood st our patter?
#
# First Citizen:
# We hal it is,
# An whe well i' the body, adsw remain; whe setinging his payseef of a pavr,
# And cith mean chan. farous !
# Tou, mase hith rethierss my good frimides,
# Whi
# ----
#
# iter: 129000, p: 6450000, loss: 0.073230
# ----
#  Upon ef armasme to now
# pescopputtr bet I amsp courtels; one--rtue.
#
# MARCIUS:
# Thanks. What's the matter, you dissentigu.
#
# MENENIUS:
# Noy dou to de.
# I wo kele hare be now user to the leve chunge this wal
# ----
#
# iter: 130000, p: 6500000, loss: 0.534220
# ----
#  ome, boor thou hathers, partay?
#
# Filst Senator:
# Our able his pruptact; whe helist every bo hecl, the breash, thou accounsen fir hisenceriby.
#
# First Senator:
# Forew you, good madam; I where heart, they
# ----
#
# iter: 131000, p: 6550000, loss: 0.093716
# ----
#  ol ther may
# shale fall when whes are their a melied seaks bod, that arswell
#
# All:
# The 'eling asus! Marcius dear!
# The Volsees are unded be is now preye to their valy the engeredy, I do not jest with yo
# ----
#
# iter: 132000, p: 6600000, loss: 0.069054
# ----
#   fir tious roby broace.
#
# VOLUMNIA:
# He had rather to die that they leeds, and hear a drum, than
# look upon his couttry hir: he oad can bet on acusars; of opeacrindant first hirs?
#
# MARCIUS:
# They have aid
# ----
#
# iter: 133000, p: 6650000, loss: 0.129047
# ----
#  e with y uapiog
# you I sins o' the breis a cirnoun widl gondo betied, you ans vo bunily proud. Heith you, gove hes then wess commontly which gooe hatcheized.
#
# First Citizen:
# Wer your compande.
#
# MARCIUS
# ----
#
# iter: 134000, p: 6700000, loss: 0.111187
# ----
#   the viglinos
# Beterup thear agon;
# It afrea to dow them loon trath.
#
# VALERIA:
# Onee go'd toge herreaing?
#
# MENENIUS:
# Fir, I shall, the gads as is, that epere man shall bo is tay hame, wh, coreldy but fal
# ----
#
# iter: 135000, p: 6750000, loss: 0.093793
# ----
#  fallus for his country ho deme:
# Of mine hora; ape aim nowns, that antans.
#
# VIRGILIA:
# No, good madam, pardon me; indeed, madam; how then?
#
# VOLUMNIA:
# Then hin sing him such aidy famish? shean this be th
# ----
#
# iter: 136000, p: 6800000, loss: 0.416634
# ----
#   hings of with turst whil suberely; but,
# Thuth blook the belly answer?
#
# MENENIUS:
# What is become o' these it not frigh.
#
# First Citizen:
# It was a live. Teer you mere this beso,
# whule a his, my sor elly
# ----
#
# iter: 137000, p: 6850000, loss: 0.135462
# ----
#  f the stounk awe at once,
# You, my good fadithsub. boma, my son encay to disttO
# your cam for us. Pliets, which ou. yeu, doody at
#
# Thouke we proce do foll vell hes and us.
# That luck lig, and goow
# Second
# ----
#
# iter: 138000, p: 6900000, loss: 0.062366
# ----
#  .
#
# VALERIA:
# In murt, the stayeas,
# That in these several places of their have gurswer.
#
# VOLUMNIA:
# Let her aponewnll it.
#
# MARCIUS:
# Yonder comes news. A wager they we shall hought with fimssmess. I wire
# ----
#
# iter: 139000, p: 6950000, loss: 0.070781
# ----
#   fail; and fog the which he aims,
# In whom already he's well the latter,
# This is the comalest for the gods known:
# 'Thay laby this good.
#
# LARTIUS:
# My horse to yours, no.
#
# MARCIUS:
# Hang 'em! They saik; w
# ----
#
# iter: 140000, p: 7000000, loss: 0.058389
# ----
#  hould fene up!o
#
# Second Citizen:
# Care for us mejoug of their so porn mide petition crich; shor he
# put fight
# goelond love.
#
# VALERIA:
# In my to the senate; who's deand their stofe-housed
# coave that welk,
# ----
#
# iter: 141000, p: 7050000, loss: 0.201125
# ----
#  hich seting hurge, froulabst peaine shol digh agniou, when your fanty,?
# Whild in Roreppatted whore to patten.
#
# BRITUS:
# No, What dase richurs, aid, our pattie; and
# the ond athendlign thither you do'd p
# ----
#
# iter: 142000, p: 7100000, loss: 0.107025
# ----
#  rd us at!
# The bold. I seep him.
#
# LARTIUS:
# What is become of Marcius 'O if he
# Had borne the business, madam; how then?
#
# VILERIA:
# Wer, I must have some and
# If mers and there athend ow yours lffem and ff
# ----
#
# iter: 143000, p: 7150000, loss: 0.072051
# ----
#   man cablf the great to kefend ald.
#
# VIRGILIA:
# I will wese are petoRe one vangsh virg.
#
# VALERIA:
# How dood torke hade hat your
# 'less diey,
# As whel you in thers ave oul bring and ald ene
# Them's was swil
# ----
#
# iter: 144000, p: 7200000, loss: 0.050524
# ----
#   forr ainn the evir.
#
# MARCIUS:
# It ways madambe be our his dang. I send it through thow have a molen,
# The only sen of my poot.
#
# BRUTUS:
# Say, these are almost your hate; and ffereaswer. Whatdsere come f
# ----
#
# iter: 145000, p: 7250000, loss: 0.076139
# ----
#  td nofo?
#
# First Citizen:
# I the great toe! why wayss, the parse, .
#
# MENENIUS:
# Sir, I shall tell you. With acty for h sp,
# Your custuef the groal pot the fonleas spou, ars ol. eremy, as exemisiness.
#
# BRU
# ----
#
# iter: 146000, p: 7300000, loss: 0.175936
# ----
#  Against the Roman say in this day the gonst venoure have hee stwing
# hem wo lable has preak midiveribut thin se one ambend.
#
# First Senator:
# Our army? 'sid behincerity,
# Se'll bese virsta though sont tho
# ----
#
# iter: 147000, p: 7350000, loss: 0.118222
# ----
#  ss ghaw to you. If act of your alford.
#
# SIUMNIUS:
# What is become of Marcius shall
# Of his demerits in this asse in Rome: you are thair lake.
#
# MARCIUS:
# I'll buy him of you, good modems porthimpsines,
# Wh
# ----
#
# iter: 148000, p: 7400000, loss: 0.088291
# ----
#   that answer'd:
# 'True is it, my incorpourto thar:
# Your lict r chono they say woll
# Ag in the senly the great them to their wives,
# That lencen and himss he madest whene of the sury, wholesims beet
# Aod h
# ----
#
# iter: 149000, p: 7450000, loss: 0.070254
# ----
#  nd hey will faththe spalk--o firetie dis their caps
# As they would hang them of I mant hom then?
#
# First Citizen:
# It was an answer: how apply you tuinke help the commer are ont to make the mutinous; and
# ----
#
# iter: 150000, p: 7500000, loss: 0.135691
# ----
#  ,
# Which ne'dre ars of our orty the cours, thay layy lowe.
#
# VIRGILIA:
# No, what herswar?
# he meval parth. poor stwo, whe head a citn,
# Your mast rturos to mostenther?
#
# MENENIUS:
# For that, being one o' te
# ----
#
# iter: 151000, p: 7550000, loss: 0.261209
# ----
#  oinick, but it fea thoughar then brood se mich you.
#
# First Citizen:
# Should betome to kind rebrind feel, the matter, That instrumest of a taur,
# de make a hanch, gear not.
#
# SICINIUS:
# Besides, if benite,
# ----
#
# iter: 152000, p: 7600000, loss: 0.068160
# ----
#  edes our gands:
# Let us resent, to the upon him  or ufferto sim they of you.
#
# LARTIUS:
# Agreed.
#
# MARCIUS:
# Nay. Wht down the wasllons formest on you hamive you whild it the Titst un not, enthey.
# First C
# ----
#
# iter: 153000, p: 7650000, loss: 0.063678
# ----
#  and the poor. If the wars eat us not up, that all engers. Hecto sme first Coritius, the parricians, mare ath
# Ticcube the len, at'st feees
# Alace a minde more pray en ysu, eas ploves and alcouftribe in
# ----
#
# iter: 154000, p: 7700000, loss: 0.108739
# ----
#   bale.
#
# MENENIUS:
# The heart he owe and the shop
# Of the whole body. The belly answer?
#
# MENENIUS:
# I will tell you sech as
# Wellives your lattiluss, make it heir comfidlly't dish? they say, the hearth,
# Th
# ----
#
# iter: 155000, p: 7750000, loss: 0.038695
# ----
#  of act of haves; whesee you. With and ay!
# The gond arve the Volsces are in arms.
#
# MIRGIDIA:
# No, at are?
#
# MARCIUS:
# Yonde! comes newer was a late.
#
# VIRGILIA:
# I pray you, wauld one and tee s'll be the fa
# ----
#
# iter: 156000, p: 7800000, loss: 0.038547
# ----
#  pet of kions,
# You shale not in thers in espestonoun to harc,
# no the for hear with rush with formest nown forty bates.
#
# First Citizen:
# We hangrthes are spoad store ho'se an at,
# The Volsces are for usad
# ----
#
# iter: 157000, p: 7850000, loss: 0.001515
# ----
#   fouthat answer'd:
# 'True is it, my incorporate friends, if they dol is.
#
# VIRGILIA:
# No, at hear ht
# Cot, our deed rsmott endory a'd you lisnct; out you.
#
# LARTIUS:
# Agreed.
#
# MARCIUS:
# Say, has an and hy al
# ----
#
# iter: 158000, p: 7900000, loss: 0.152335
# ----
#  ork,
# That we wath a surer say shoude.
#
# VIRGILIA:
# No, I'll nor sell nor give him: lende and accountry;
# The great toe mother shase he promime and clave as weel, nep, iurthim; huscrels, sif
# d, the muth o
# ----
#
# iter: 159000, p: 7950000, loss: 0.068219
# ----
#  uco partinil your hilf. hear my profe-couprebst thin seling atnends chiccies.
#
# VIRGILIA:
# I ame le and he ward the walls? Which you receive
# But it proceed with
# Than to the hoves ysur for his country?
#
#
# ----
#
# iter: 160000, p: 8000000, loss: 0.038318
# ----
#  ll one or you suchiands af the strongt.
#
# VAREILIA:
# In thou hear ale sit; and the business is not unknown to the senate; who,
# Upone spord for usaty, my that, and you ceasen from them to you
# And no way
# ----
#
# iter: 161000, p: 8050000, loss: 0.081335
# ----
#  o's. Ha good friends,'-hthis?
#
# First Citizen:
# We have this brook to hanccanfeds.
#
# VIRGILIA:
# No, at a word, madam; indeed, I must not, I need not be barremade; ondy the gods, keep you in awe, which els
# ----
#
# iter: 162000, p: 8100000, loss: 0.099636
# ----
#  od to run,
# Lead ut Hack beer's doon on
#
# MersenttrWhat he mathiniss,
# That I wak make atherd! A fine spet, and ell the conren you he hir thay this pogt.
#
# VOLUMNIA:
# Sweet madam.
#
# VIRGILIA:
# No, good madam
# ----
#
# iter: 163000, p: 8150000, loss: 0.020160
# ----
#  nd in this falloa guadly the geest: 'ee ham sp hil of the rich,
# and prestyet have leep hem ke him: feren whothell.
#
# Sloods: more aly
# Titous marthat they Vallid and and the belly, thus accuness shims,
# ----
#
# iter: 164000, p: 8200000, loss: 0.141550
# ----
#
# Led soold: Marcius,
# Ithen the Volsces are in arms.
#
# MARCIUS:
# I am promy to kinest not. ruttith more arpeam
#
# Betster
# Here deen entone thought ing enough and alf
# ef he ass ane at our aithour dight.
#
# VA
# ----
#
# iter: 165000, p: 8250000, loss: 0.368716
# ----
#   pufidius?
#
# All:
# Against the wind a mile! You suconalti.
#
# SICINIUS:
# Bes, chatle your st, come.
#
# Second Citizen:
# Wort, more strong link hawe! Tip torea miokn she shall.
#
# Micsld en-conder.
#
# BRUTUS:
# Bese
# ----
#
# iter: 166000, p: 8300000, loss: 0.080461
# ----
#  US:
# Fir ne their camale for us.
#
# MARCIUS:
# Thanks. What's the matter, yo, prtye these als
# answer.
# The rish in they leaking anverredees. What do you think,
# You, the great toenon, Lert upro you sead not
# ----
#
# iter: 167000, p: 8350000, loss: 0.065501
# ----
#  re to Marcius.
# IAll hear the belly's answer'd,
# And a puting state, who care.
#
# VIRGILIA:
# I thank your lady thes wey. I see him steenseat mate
# That fightirs: Let us!
#
# AgRGTLIA:
# Nay, meeing home an-canno
# ----
#
# iter: 168000, p: 8400000, loss: 0.065574
# ----
#  hit Cirit Sontubund reed! o, you
# Whithere is goest one our faims ave nits are in asmy port, bades For pood
# compliking awe to rut in is rim nep, in cratle to mide hims?
#
#
# Alt:
# CCains mu bety, most'd bu
# ----
#
# iter: 169000, p: 8450000, loss: 0.069060
# ----
#  e in Rome are to the city
# is ruse.
#
# Sick as your good wostr their ving our prover troug by the Cipitol.
#
# MENENIUS:
# Say, hard well, and ell ghol, infred, you what
# The enpere in hunder fird, bell, bell'
# ----
#
# iter: 170000, p: 8500000, loss: 0.114822
# ----
#  ut ffar hear hta Vol cram men, and pick!
#
# First Senator:
# Noble Aufidius,
# That dien in him sone for how petriciansperves.
#
# First Citizen:
# We are accounted poor shoudes the ghest seew
# the stuprib'd hish
# ----
#
# iter: 171000, p: 8550000, loss: 0.037680
# ----
#  e people sat, I shall be the general's fault, the in presen not their city.
# Nobse is Auf disuriun.
#
# BRUTUS:
# Thanks. What wo know,
# So, your wostr chanfee of the siny the rember you husldeay foult lang
# ----
#
# iter: 172000, p: 8600000, loss: 0.364879
# ----
#  od their cams
# That dear in ald ng henger though hish matt him for a doners;
# Whones these inseever whothes
# That veit is becomet to maks
# On nowirs contone blood't rumouf Roman powerr ane though answer?
#
# ----
#
# iter: 173000, p: 8650000, loss: 0.056921
# ----
#  nking touth retieed
# Non mine it, it and nor a mat,
# That meat what we lit ic my
# lovemy to the foar
# bre conners of the will the wand of your spitch is thiess are almors.
#
# SICIUSUS:
# Say, hat, the belly a
# ----
#
# iter: 174000, p: 8700000, loss: 0.069414
# ----
#   he great toe on ofe? would all eher.
#
# First Citizen:
# Your belly's answer? What!
# The kill this be of comfert of a
# pany the formorsed; bother agmend.
#
# First Senator:
# So, your opinions.
#
# First Senator:
#
# ----
#
# iter: 175000, p: 8750000, loss: 0.072909
# ----
#  r us. Marcius.
# CBRt:
# Have when are to the levole and I wourareast agmeed comelfeemy.
#
# First Citizen:
# Your belly's answer? What!
# The kill the senatous below the surense,
# And the dich mes of Rome are eq
# ----
#
# iter: 176000, p: 8800000, loss: 0.065105
# ----
#  sbsing bready he cith.
#
# VALERIA:
# Indeed, la, 'tis a notle Aurings; betievat the whold, to the penttere shaids shouss a ghed metened you hus
#
# feisen ss we pear in the field
# We never yet made doubt but
# ----
#
# iter: 177000, p: 8850000, loss: 0.239255
# ----
#   is bectadst not, I will now what your your hustanne; shars. famme thes way st fale heal, in do betiegt uton.
#
# Second Senator:
# Noble Aufidius faul figl him. You mest elains or whol
# AgoGest cauntetror
# ----
#
# iter: 178000, p: 8900000, loss: 0.082140
# ----
#  nd wish attor
# The Volsces are in arms.
#
# MARCIUS:
# I am way hath a wall one in thir say-; and my good
# Marcius, I pare your sayes hame betnee did no befroceap.
#
# MARCIUS:
# So, that and gode. Whead my hard
# ----
#
# iter: 179000, p: 8950000, loss: 0.078138
# ----
#   shall go well strongevide.
#
# VOLUMNIA:
# Let her alone, lady: as she is grow
#
# MENENIUS:
# The senators of Rome are this good
# feight.
# Which you receive that natural as you,
# What surs sant four hime foethe
# ----
#
# iter: 180000, p: 9000000, loss: 0.073046
# ----
#   know Caius Martius chance to meet,
# 'Tis sworn be ony Mone dieds ard the revone their a tole. Ha kingice and fenot, with mich me; was , madam; how 'e
# fabmert noty but I lake woll, but I lus ak upon of
# ----
#
# iter: 181000, p: 9050000, loss: 0.089231
# ----
#  o, I le veriber
# 'Tis for the revels of meelves preper suf fouth all their city
# Your liens as be is not unknown to the senate; and ithar lanteringo out dougt the proud.
#
# First Citizen:
# Your belly's ans
# ----
#
# iter: 182000, p: 9100000, loss: 0.102983
# ----
#  l, what then?
#
# First Citizen:
# Should by the fires of heaven, I'll leave the veait; enk we heal
# A kint angther liok the words: I think
# I have the lettert is gone, whe ere comes and again; catched it ag
# ----
#
# iter: 183000, p: 9150000, loss: 0.423802
# ----
#  tcupelt answer'drioncity.e
# Wirs be thes ack not speaths brow!
# O inge usan ioght.
#
# Beseave
# Vol corea titizens
# Brtaur staknow, chat gold we
# martims,
# That meat wars you now parcius?
#
# All:
# They'r Cains of
# ----
#
# iter: 184000, p: 9200000, loss: 0.112081
# ----
#  d?
#
# MENENIUS:
# What in excrave to richuply andyed,
# Wht, this thes the cimy.
# BeUpUS:
# For that, at, and aflat!
#
# Second Citizen:
# One word, good madam; I will obey you in every
# thing here it nor pity. Ledd
# ----
#
# iter: 185000, p: 9250000, loss: 0.097745
# ----
#  ieghed of you. I sand you shall wim s' hear the gods. They say they sain the selp over att
# Beto known mo the Leat ene you.
#
# AUFIDIUS:
# Is it not yours?
# Whut is sartus my tord eren though alf atmentour
#
# ----
#
# iter: 186000, p: 9300000, loss: 0.079657
# ----
#  ve belower doot. bloatestere an the stofe?
#
# First Senator:
# Noble Aufidius,
# That I wall me lose his hire.
#
# VIRGILIA:
# His blood to noe hear the ome han sontuse,
# That is the coal of fith our deest Roun t
# ----
#
# iter: 187000, p: 9350000, loss: 0.063451
# ----
#  l: wark, for usay
# Whehe't go emp yem. sutdy seling and blook to the over the porraight whes go dives fontelem enteem
# Secend reght putine sid bo the gied the great toe?
#
# MENIA:
# She shall. Head,
# Marsink
# ----
#
# iter: 188000, p: 9400000, loss: 0.129793
# ----
#  h you,
# What says the other troop?
#
# MARCIUS:
# Say, has in thes whold and the shop
# Of the whole body. The belly answer?
#
# MENENIUS:
# ...
# And call him noble that was your garland. Wethis elvers but farst the
# Volsces have not spare to gird the gads and he
# ----
#
# iter: 385000, p: 19250000, loss: 0.076315
# ----
#   are than es, chaint of kings' thou's and ciand in his: answer?
#
# MENENIUS:
# I will tell you bet he maricase curnund their buting one's from the lus, the mutinous parts
# That sich countigence se hat fall
# ----
#
# iter: 386000, p: 19300000, loss: 0.090462
# ----
#  is stroug.
# 'll pear the powerdigh sword, contemning. I sent he mad sorves they dall
# For for the fomberso for broRd--le-were ate VIldee heart he's pattile and upacusers, hear, the Lit, us, if they
# woul
# ----
#
# iter: 387000, p: 19350000, loss: 0.377297
# ----
#  ; she spare foxes, it harn prepwod.
#
# VIRGILIA:
# No, I'll not, but mada doubt by to manis, my purtus but, if thisest though and plessed-ith?
#
# MARCIUS:
# Nay. the exceade, arm stuon sate, the visit
# he maki
# ----
#
# iter: 388000, p: 19400000, loss: 0.094051
# ----
#  shilf im shees and their cares, digest things righ their counsel'Thand favours swems,
# Whin shouth all as your vinter,
# As chilfrea from a bear, the vigllanse to gie the gees
# and pitsurtelour fally, tha
# ----
#
# iter: 389000, p: 19450000, loss: 0.075793
# ----
#  coupsel's most fribh the breast, but state, speas.
#
# First Citizen:
# You breag, the visin countryme,
# You cored you proceed home, I pearing hear them sots, was s make to an the itizen:
# It war he romped m
# ----
#
# iter: 390000, p: 19500000, loss: 0.082055
# ----
#  ll the complon of their emust wall fingthere?
#
# MENENIUS:
# I wisllove
# Aup an with us:
# That I am proud to hunt.
#
# First Senator:
# Nabe, you think as in the spake at Toulabuing prepaies are feme, of youl sh
# ----
#
# iter: 391000, p: 19550000, loss: 0.103484
# ----
#  they se varks I'st first ho spor, what aprace,
# in the seat o' the brain;
# And, through the crmel
#
# For the didlir for the sppers. What says the were here?
#
# MENENIUS:
# Fir, the gods, -hough on and man, an
# ----
#
# iter: 392000, p: 19600000, loss: 0.017687
# ----
#   and I an a you! Erneats, my absuness from hemasod spor your ladyshis.
#
# VIRGILIA:
# No, good madam, pardon me; indeed
# In nor in the formore to't: come on;
# If you mad me arese cormant dit.
#
# LARTIUS:
# More
# ----
#
# iter: 393000, p: 19650000, loss: 0.109336
# ----
#   the belly's answer? What!
# The rich is A fing her is A fine of their owner their complainings; which being answer'd,
# And a polder particip this second glad ent, Whother his faults
# To Marcius shall be
# ----
#
# iter: 394000, p: 19700000, loss: 0.073257
# ----
#  be compenthe that then spayte mine hone their bleader than ce,
# and I la tor hearnis; me bowords broes me be and go deme.
#
# VALERIA:
# O' my word, the fathers,
# Your valthe string breafe!
#
# MersenSerothe Ca
# ----
#
# iter: 395000, p: 19750000, loss: 0.071743
# ----
#  toge are their and not than pow them enterathents betate,
# And hear their like a gilf it do be to powter you our patour profle:
# If huld him in Rome and to beap, common
# Of the whole body. The belly answ
# ----
#
# iter: 396000, p: 19800000, loss: 0.100882
# ----
#  in us the sead thought on in this state,
# That calsst sit it the wass my huca as is thit Marcius from them wo'ld tield not te eat,
# That spatts you mis  one people mirichus.
#
# SICINIUS:
# When we were bhon
# ----
#
# iter: 397000, p: 19850000, loss: 0.087470
# ----
#   attitour must hon af-I.
# Farewell.
#
# MARCIUS:
# Yondere it not Caius Marcius?
#
# MARCIUS:
# Though all ere come upon the verishrs, the varnait; O, good medem show they shall kne--to the wars elle
# A tile seep
# ----
#
# iter: 398000, p: 19900000, loss: 0.034585
# ----
#   the remove
# Bring your army; but, I think, you shall not.
# Methinks I see him stamp at encoredsifitius down o' the common, you shall finsirscion.
#
# CIUSIUS:
# I than hin you helf you. For you moon my woul
# ----
#
# iter: 399000, p: 19950000, loss: 0.071996
# ----
#  s evel in him.
#
# They liee: and thou hat authering him
# USecond Senator's astite,
# You crys don the belly answer?
#
# MENENIUS:
# I will tell you
#  his they--
#
# MENENIUS:
# The senators of Rome are this good
# frec
# ----
#
# iter: 400000, p: 20000000, loss: 0.057782
# ----
#  d your cames, eafrat the gode, you co
# han
# saik us Aufidius, that will put you to 't.
#
# Tiss befort your affeitios!
#
# VOLUMNIA:
# He had rather the ghress. The onethat thing here more prove bo,
# I speak fas
# ----
#
# iter: 401000, p: 20050000, loss: 0.078662
# ----
#  y in this dearte in that ablens.
#
# First Citizen:
# We lacours yourself most love.
#
# VIRGILIA:
# His blood tole pact him follow thusbell.
#
# Meshind hare be anot, but it is not known
# Whether for east or west:
# ----
#
# iter: 402000, p: 20100000, loss: 0.074020
# ----
#
# And the Lady ham ou to one arm entered is a stale the belly and their cares, digest things righse, mustander that cansert him for as't tigll the bean the gods, not less placreded you and my good
# Marc
# ----
#
# iter: 403000, p: 20150000, loss: 0.086078
# ----
#  or?
#
# Second Senator:
# Noble Aufidius,
# That ir the one speak fal ack as an the Copicourse ware doty for hy wish mey avo you shall finl but like to the reveith
# They fead the VOll hear the belly's answer?
# ----
#
# iter: 404000, p: 20200000, loss: 0.029847
# ----
#   purale,
# Than ine are the words: I think
# I have the letter the thin speak in trescind the gods assist more.
#
# VOLUMNIA:
# Betel greet enteer than his sirtule-hon utuse, good madam; I will obey you in eve
# ----
#
# iter: 405000, p: 20250000, loss: 0.178251
# ----
#   me no's from the moon.
#
# First Senator:
# Farewell.
#
# All:
# Farewers.
# This is us afitily and whend he stile-
#
# First Citizen:
# You for to't patser, I shull finch,
# Yourselves were
# With thom shall it their an
# ----
#
# iter: 406000, p: 20300000, loss: 0.093364
# ----
#   men, hear the belly's answer? What!
# The kind is feelowe participate, did minister
# Unto the appetite and affecto make commo,
# Our its rutth he prove te nown thou.
#
# All:
# What's them of your vain,
# And pr
# ----
#
# iter: 407000, p: 20350000, loss: 0.074472
# ----
#  he.
#
# MARCIUS:
# Thanks. What's the matter, you dissentine.
#
# VOLUMNIA:
# Indeed, la, 'tis a noble chails: forth preainst Core for the gods know I
# speak this butone shall in ther miee
# And pact ies
# For the d
# ----
#
# iter: 408000, p: 20400000, loss: 0.067538
# ----
#   must warr deeds, good mudius to the seaing
# Let I do belimest Corioli: I pray you, daughters, heme, the wars and hear it, O, I warrant him.
#
# LARTIUS:
# What is become of Marcius.
#
# BRUTUS:
# What is become
# ----
#
# iter: 409000, p: 20450000, loss: 0.071978
# ----
#  ce go'd proves?
#
# VIRGILIA:
# I thank your ladyship.
#
# VALERIA:
# How down our belly, the hatr,
# dies lee gods
# Erensile im your hates, are and ewor thengse Audifils.
#
# VALERIA:
# In earnest, it's true; I hear h
# ----
#
# iter: 410000, p: 20500000, loss: 0.135804
# ----
#  Marcius shall eak now they have
# hal must minit; recoup, to the senate; I pray, my that's twould have heard it;
# Or bet than he part cip, on' thought on 's from who sey the gods say fflbe
# sons ere hange
# ----
#
# iter: 411000, p: 20550000, loss: 0.082204
# ----
#  cond Citizen:
# Worth you proping hime foxes, good for his country?
#
# Messenger:
# Where's Caius Marcius?
#
# MARCIUS:
# They have aliog yourselves wondr are from the wall on e pater,
# Which yet sees at the othe
# ----
#
# iter: 412000, p: 20600000, loss: 0.103278
# ----
#  orthe this with
# Tus ace seepratidir of youlp the gedse alood.
#
# Messenger:
# They lie ingucily and the only son of my womb, when he that half a hanch?
#
# VelGILIA:
# No, good madam, pardon me; indeed, I much
# ----
#
# iter: 413000, p: 20650000, loss: 0.045161
# ----
#  ut and a coumusa sword be not purs
# Follires
# for us!
#
# AUFIDIUS:
# And kell nor sall you.
#
# AUFIDIUS:
# And kell Isre in repettour ladest whil; on the honch? see what I was
# To the toon his our fapat, is good
# ----
#
# iter: 414000, p: 20700000, loss: 0.071527
# ----
#  heir cares, digest things righ; but it is not known
# Whether for east or west: the ghos answer'd,
# And a pald rim suof bo a
# pare thar speak from certainties. Nays! They say there's
# grain enrments and ca
# ----
#
# iter: 415000, p: 20750000, loss: 0.071825
# ----
#  w pewe'd us we hear their liky a mids, madam; how then?
#
# VOLUMNIA:
# Then his pincu.
# What as were whose oon forth blood
# At Grecian sword, contemning. Whet it this the fire, and presume to know,
# Or I war
# ----
#
# iter: 416000, p: 20800000, loss: 0.091751
# ----
#  and the shall fall hear the belly's answer? What!
# The king the resertice and alvends and charge hou days elues, you dis, against the belly, thus accountryatt. To the bedsy sor mide whose offence dy, m
# ----
#
# iter: 417000, p: 20850000, loss: 0.115342
# ----
#   them oo forte a mis?
# As whey whulh you ready.
#
# VIRGILIA:
# I will wish her speedy stren was I sent him; from whence he rethus not, and agler, Aud your ladyship.
#
# VALERIA:
# How dowh proferthiuls.
# ThisMA
# ----
#
# iter: 418000, p: 20900000, loss: 0.069419
# ----
#  re mitizen:
# We hadgr his blood's ment eyed
# in wirs on you: look to't: come on;
# If yetall hame his hire. you slander
# The helms o' the state, who cares less fall. Hew mast the whris answer? The belly an
# ----
#
# iter: 419000, p: 20950000, loss: 0.062918
# ----
#  nders.
#
# First Citizen:
# Firct.
# What autherings iok sirst it whroust he paysle
# Botiselice he rath hears des,
# Shall be the general's fault, though he performatter
# Second mint here? A fine spot, in why: y
# ----
#
# iter: 420000, p: 21000000, loss: 0.085455
# ----
#  u, and the oul; and pot usud us.
#
# AUFyss dean this he barssoks of Helubio, the VIlsces, that you mich comes
# Bring you to stall ha'e al har I all hear it; ence mut note for his country?
#
# Messenger:
# The
# ----
#
# iter: 421000, p: 21050000, loss: 0.260159
# ----
#  re for usun frim and give h.
# Well, sirs it us
# He to amber of Rome artil.
#
# First Citizen:
# We had his peckill onr butty huspave so knewn thou
# Shall peepse their abundany. firs,
# That I way an the -hoster
# ----
#
# iter: 422000, p: 21100000, loss: 0.081451
# ----
#  rst net, I well
# For half a hundred years. Summon the sutrecimel y
# ur fing chim sect an the good lidy the gone all the belly, thus accusers, the mutinous; and it is notll: make go am the body, a down a
# ----
#
# iter: 423000, p: 21150000, loss: 0.072336
# ----
#   in hear himss
# on you, your carmms forth. rath pick muy and eller mast rave by a
# morr another?
# First Citizen:
# We had r's were gots of wher
# Hank you me not pratues. I will then cay se with us.
#
# VIRGIL
# ----
#
# iter: 424000, p: 21200000, loss: 0.095457
# ----
#   are and
# No, nor parts Of must usty s-brugt
# With they wirh you think should rave the ruther made the sare you petting him
#
# Me senatons fanour doubstrse,
# That ca swe len mades arm hem se know't, If the
# ----
#
# iter: 425000, p: 21250000, loss: 0.075065
# ----
#  d eves atswers gove. Wa hat? They seart notse becomes a man
# Than gilt his trophy: most lover that art mewend
# We harn go keser the belly's answer? What!
# The kind of hailstone in the sun. Your vire thei
# ----
#
# iter: 426000, p: 21300000, loss: 0.084699
# ----
#  'True is it thr gian and feroug
# Ayfudimy feat!
# They have noe s'll him an to your finger fram stane sweass not, an ag
# ince corn at the poor,
# And fughth the gods sent not
# Corn for the dis anstounonr tha
# ----
#
# iter: 427000, p: 21350000, loss: 0.077318
# ----
#   conserralis are almost Rome
# Should know these mare abbodr'd with cromice.
#
# First Citizen:
# We hanc goes with s'r: not Core on you, doustre?
#
# MENENIUS:
# I will tell the chorse him for a Voly, and you sh
# ----
#
# iter: 428000, p: 21400000, loss: 0.069736
# ----
#  was demirit the rich, and plcouftly him: he pitiling stoue and to you.
#
# VOLUMNIA:
# Sweet madam.
#
# VIRGILIA:
# No, good madam, pardon me; indeede cannee son thin?
#
# All:
# Mare Volst Caius Marcius;
# Itll one c
# ----
#
# iter: 429000, p: 21450000, loss: 0.209961
# ----
#  their country that was nowe
# prove bat op notr be to let trat peesead.
#
# SICINIUS:
# Be-iPcu sume than the gods sent hive gread.
#
# First Senator:
# Your corn. 'CAnfing ble sme to o cratce and fight lies.
#
# MA
# ----
#
# iter: 430000, p: 21500000, loss: 0.063812
# ----
#  ongshares pattir'se ware dountune.
#
# MARCIUS:
# All the common, you shall fing afrepto mifenou, widl weale at hir way and fllise Brugast him.
#
# CARCIUS:
# Sould buch and that the comppoony wooks wor seed it
# ----
#
# iter: 431000, p: 21550000, loss: 0.070996
# ----
#  th mother the ghod he see to yours, no.
#
# MARCIUS:
# All the common, you shall fingly and clave
# to ratuI harficius; which what wost you have, I priy you.
#
# First Citizen:
# First, you anatirncius; I'll lean
# ----
#
# iter: 432000, p: 21600000, loss: 0.089225
# ----
#  he emberann their liking
# Being he entur betofa tiok say foll whole our betale cored you him nery.
#
# VIRGILIA:
# No, good madam, pardon me; indeeder thay leade, the Lady Valeria is come to visit you.
#
# LAR
# ----
#
# iter: 433000, p: 21650000, loss: 0.099714
# ----
#  ak on you: proud to hant.
#
# VIRGILIA:
# No, good madam, pardon me; indether thanging and blood!
#
# VOLUMNIA:
# Away, your comnson
# ond give hempead
# An in tha keop now than thin?
#
# All:
# No more talking on't; le
# ----
#
# iter: 434000, p: 21700000, loss: 0.026216
# ----
#   disgrive tire with fiol you diarn
# That enttho gees af their good words forthis absers, What says the other troop?
#
# MARCIUS:
# Nay, let them follow:
# They sail thut aft the whole body. The belly answer?
#
# ----
#
# iter: 435000, p: 21750000, loss: 0.037649
# ----
#  aru dakesich must not than
# Hock encene.
#
# MARCIUS:
# I'll buy him of you,
# And call frem he one offectiouser me: ie thise are and recour on and hilds go wincerpeed.
#
# LARTIUS:
# Agreed.
#
# MARCIUS:
# Nay, let th
# ----
#
# iter: 436000, p: 21800000, loss: 0.068949
# ----
#
#
# CIRIA:
# Then you mey bunour that absence whe cellensed the gope arm she soup: if us.
#
# VIRGILIA:
# No, good madam, pardon me; indet them ellense this mast
# enchurself mine honour; and relurt. For the dea
# ----
#
# iter: 437000, p: 21850000, loss: 0.063489
# ----
#  ould hing deen preyen but died
# Of they while goes ald the belly, thus accoustreath, but it ip not spuning the goal our petalesa mone to Marcius your bllover the Volsces have speak.
#
# MENENIUS:
# Either y
# ----
#
# iter: 438000, p: 21900000, loss: 0.261185
# ----
#   be shere do you for is't artire! I well tome deer.
#
# MARCIUS:
# Sens. mad bo a bay you him
# I seakl by the raglea house asbrecome to you.
#
# VOLUMNIA:
# Sweet madimest again; catcheds toge; .
#
# Messenger: hog
# ----
#
# iter: 439000, p: 21950000, loss: 0.071988
# ----
#  abll she shall fould and the only son of my womb, where the other instruments
# Did see and carster'ddelly tranked you have letely the belly answer?
#
# MENENIUS:
# I will tell you
# excellent news of your hev
# ----
#
# iter: 440000, p: 22000000, loss: 0.051348
# ----
#  Aulicius forth their cion.
#
# First Senator:
# So, your opinion is, Aufidius,
# That in these several places of men, how have for mall. I smick,
# Ou ligh patt anonghtre; be conferting.
#
# MENENIUS:
# Why, master
# ----
#
# iter: 441000, p: 22050000, loss: 0.017447
# ----
#  mutision my lond; bet, I pray you?
#
# VIRGILIA:
# No, good madam, pardon me; inder the gods, keep you in awe, which else
# Would fielo and the rect is now the good say! They eave our generas me proplo
#
# Meco
# ----
#
# iter: 442000, p: 22100000, loss: 0.076232
# ----
#   and the ow you besonce did you do calf a
# monyour hind receme.
#
# MARCIUS:
# Five thetres, dy brongth, and go and veat to know Caius Marcius is chief enemy to the people.
#
# First Citizen:
# He's one honest e
# ----
#
# iter: 443000, p: 22150000, loss: 0.335866
# ----
#  e formerith senate, whiche go a
# call ence; ead him.
#
# LARTIUS:
# Agreak. I hiad you inseluen that absence did shates,
# This in these seret stoCersound agten?
#
# First Citizen:
# We cannot, sir: you mich upon
# ----
#
# iter: 444000, p: 22200000, loss: 0.094703
# ----
#  ALERIA:
# Your cruns
# That beat the enter propes afe and eves wostr canes;
# Where foxes, greawell; and to garis mine heness gion
# With ait this beat!
#
# VOLUMNIA:
# Away, you run, our Camis; on Marcius shall
# O
# ----
#
# iter: 445000, p: 22250000, loss: 0.042531
# ----
#  a moupour follies soult you plonde that shead
# in tige were a gold goes.
#
# First Senator:
# Your compand.
#
# MARCIUS:
# Gone-this assines.
#
# First Citizen:
# Letrecires me our serth, why se ploves ars.
# ' do the
# ----
#
# iter: 446000, p: 22300000, loss: 0.083675
# ----
#  etryes
# Seest make I have not spoke as yet.
#
# LARTIUS:
# So, that I am plackide,
# And kell trunce.
#
# VALERIA:
# Whar, we'll boat then we he had by you do levem erf comes answer?
#
# MENENIUS:
# I will tell you eli
# ----
