# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import string
import random
import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.contrib import seq2seq

from sklearn.utils import shuffle
# Out:
# /home/florian/anaconda3/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
epochs = 20000
lstm_size = 256
embed_size = 32
max_word_length = 12

# %%
with open('google-10000-english-usa-no-swears.txt', 'r') as word_file:
    words = word_file.read().split('\n')
    
# do a little bit of cleaning just in case
def only_letters(some_string):
    return ''.join([c for c in some_string if c in string.ascii_letters])

def pad_front(some_word):
    while len(some_word) < max_word_length:
        some_word = '_' + some_word
        
    return some_word

def pad_rear(some_word):
    while len(some_word) < max_word_length:
        some_word += '_'
        
    return some_word

words = [only_letters(wrd) for wrd in words if 2 < len(wrd) < 10]
    
print('Found {} words'.format(len(words)))
print(words[7000])
# Out:
# Found 8124 words
# sandwich

# %%
# create program to generate pig latin
def make_piglatin(some_word):    
    vowels = ['a', 'e', 'i', 'o', 'u']
    ay = 'ay'

    if some_word[0] in vowels:
        new_word = '>' + some_word + ay
    else:
        new_word = '>' + some_word[1:] + some_word[0] + ay
        
    new_word = pad_rear(new_word)
    old_word = pad_front(some_word)
        
    return old_word, new_word

# test it
old_word, new_word = make_piglatin(words[-7000])
print(old_word, new_word)
print(words[-7000], make_piglatin(words[-7000]))
# Out:
# _____cameras >amerascay__
# cameras ('_____cameras', '>amerascay__')

# %%
# get dictionaries so we can convert from letters to index and index to letters
chars = string.ascii_letters + '>_'

char2idx = {ch: i for i, ch in enumerate(chars)}
idx2char = {i: ch for i, ch in enumerate(chars)}

vocab_size = len(chars)

# %%
# set up the place holders for our computational graph
inputs = tf.placeholder(shape=[1, None], dtype=tf.int32, name='input')
decoder_inputs = tf.placeholder(shape=[None, None], dtype=tf.int32, name='decoder_input')
targets = tf.placeholder(shape=[None, vocab_size], dtype=tf.int32, name='targets')

# create an initializer to init our weight matricies
init = tf.random_normal_initializer(stddev=0.1)

# %%
# set up the embedding layer
embeddings = tf.get_variable("embeddings", [vocab_size, embed_size], initializer=init)

with tf.device('/cpu:0'), tf.name_scope("input_embedding"):
    encoder_embedding = tf.nn.embedding_lookup(embeddings, inputs)

with tf.device('/cpu:0'), tf.name_scope("output_embedding"):
    decoder_embedding = tf.nn.embedding_lookup(embeddings, decoder_inputs)

# %%
projection_layer = tf.layers.Dense(vocab_size, use_bias=False)


# create the encoder LSTM
with tf.variable_scope('encoder') as enc_scope:
    lstm_encoder = tf.contrib.rnn.BasicLSTMCell(lstm_size)
    _, encoder_last_state = tf.nn.dynamic_rnn(lstm_encoder, inputs=encoder_embedding, 
                                              dtype=tf.float32, time_major=False)
    
with tf.variable_scope('decoder') as dec_scope:
    lstm_decoder = tf.contrib.rnn.BasicLSTMCell(lstm_size)
    #decoder_out, _ = tf.nn.dynamic_rnn(lstm_decoder, inputs=decoder_embedding, 
    #                                   initial_state=encoder_last_state, dtype=tf.float32)
    helper = seq2seq.TrainingHelper(inputs=decoder_embedding, sequence_length=[11],
                                    time_major=False)
    decoder = seq2seq.BasicDecoder(lstm_decoder, helper, encoder_last_state, 
                                   output_layer=projection_layer)
    outputs, _, _ = seq2seq.dynamic_decode(decoder, output_time_major=False,
                                           impute_finished=True, maximum_iterations=20)
    
# get the output from the decoder
#logits = tf.layers.Dense(vocab_size, activation_fn=None)
#piglatin_pred = tf.nn.softmax(logits)
logits = outputs.rnn_output
predictions = outputs.sample_id

# %%
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(labels=targets, logits=logits)
loss = tf.reduce_mean(cross_entropy)

optimizer = tf.train.AdamOptimizer(learning_rate=0.0003).minimize(loss)
# Out:
# WARNING:tensorflow:From <ipython-input-9-6f4fd5178e0a>:1: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %%
logits.get_shape().as_list()
# Out:
# [1, None, 54]

# %%
init = tf.global_variables_initializer()

# get test words
words = shuffle(words)
test_words = words[:10]
words = words[10:]

def one_hot(v):
    return np.eye(vocab_size)[v]

with tf.Session() as sess:
    sess.run(init)
    for e in range(epochs):
        words = shuffle(words)

        input_word, targ_word = make_piglatin(words[0])

        input_vals = [char2idx[c] for c in input_word]
        target_vals = [char2idx[c] for c in targ_word[1:]]
        decoder_vals = [char2idx[c] for c in targ_word[:-1]]

        target_vals = one_hot(target_vals)

        input_vals = np.asarray(input_vals).reshape(1, len(input_vals))
        decoder_vals = np.asarray(decoder_vals).reshape(1, len(decoder_vals))

        _, loss_val, train_logits = sess.run([optimizer, loss, logits], feed_dict={inputs: input_vals,
                                                                                   decoder_inputs: decoder_vals,
                                                                                   targets: target_vals})


        if e % 500 == 0:
            print('epoch: {}, loss: {}'.format(e, loss_val))
            
            for i in range(len(test_words)):
                val_word, val_targ = make_piglatin(test_words[i])
                val_input = [char2idx[c] for c in val_word]
                val_dec_in = [char2idx[c] for c in val_targ[:-1]]
                
                val_input = np.asarray(val_input).reshape(1, len(val_input))
                val_dec_in = np.asarray(val_dec_in).reshape(1, len(val_dec_in))
                
                prediction = sess.run(predictions, feed_dict={inputs: val_input,
                                                          decoder_inputs: val_dec_in})

                print("Given: {}, Predicted: {}".format(val_word, ''.join([idx2char[idx] for idx in prediction[0]])))
            print()
# Out:
# epoch: 0, loss: 3.984480142593384
# Given: _________doe, Predicted: lllllllllCC
# Given: _________yet, Predicted: dddhqNCCCCC
# Given: ___respected, Predicted: lldPxrSrlxH
# Given: ________trip, Predicted: Bff>cs>CCC_
# Given: ____snapshot, Predicted: bbjYUUppUt>
# Given: ____minority, Predicted: BCbb>>e>>>>
# Given: ____cosmetic, Predicted: bfffjjfWra>
# Given: ___forbidden, Predicted: llH>>aalIjj
# Given: ______notice, Predicted: llWeWrrjxll
# Given: ____ultimate, Predicted: bffeffoWSov
#
# epoch: 500, loss: 1.1736130714416504
# Given: _________doe, Predicted: aeaay______
# Given: _________yet, Predicted: aaaay______
# Given: ___respected, Predicted: eeeettaaay_
# Given: ________trip, Predicted: aetaay_____
# Given: ____snapshot, Predicted: eeettaaay__
# Given: ____minority, Predicted: eeettaaa___
# Given: ____cosmetic, Predicted: eeeetaaayy_
# Given: ___forbidden, Predicted: eeeetaaay__
# Given: ______notice, Predicted: eeeeaaay___
# Given: ____ultimate, Predicted: eeeeeaaay__
#
# epoch: 1000, loss: 1.3517146110534668
# Given: _________doe, Predicted: assay______
# Given: _________yet, Predicted: asaay______
# Given: ___respected, Predicted: aaeeteessay
# Given: ________trip, Predicted: aessay_____
# Given: ____snapshot, Predicted: aareeesaay_
# Given: ____minority, Predicted: aeeeessaay_
# Given: ____cosmetic, Predicted: aeeeeesaay_
# Given: ___forbidden, Predicted: aaeenessaay
# Given: ______notice, Predicted: aeesssay___
# Given: ____ultimate, Predicted: aaeeeesaay_
#
# epoch: 1500, loss: 1.7746543884277344
# Given: _________doe, Predicted: aesay______
# Given: _________yet, Predicted: asaay______
# Given: ___respected, Predicted: ereeeeeeeay
# Given: ________trip, Predicted: aeeaay_____
# Given: ____snapshot, Predicted: erreeeeaay_
# Given: ____minority, Predicted: ereeeeeaay_
# Given: ____cosmetic, Predicted: ereeeeeaay_
# Given: ___forbidden, Predicted: ereeeeeeaay
# Given: ______notice, Predicted: eeeeeaay___
# Given: ____ultimate, Predicted: ereeeeeeay_
#
# epoch: 2000, loss: 1.5486159324645996
# Given: _________doe, Predicted: atsay______
# Given: _________yet, Predicted: asaay______
# Given: ___respected, Predicted: eriiiiesssy
# Given: ________trip, Predicted: oessay_____
# Given: ____snapshot, Predicted: aatiieeeay_
# Given: ____minority, Predicted: oniiieesay_
# Given: ____cosmetic, Predicted: oriitessay_
# Given: ___forbidden, Predicted: oriiiiessay
# Given: ______notice, Predicted: oteeesay___
# Given: ____ultimate, Predicted: oriiieneay_
#
# epoch: 2500, loss: 1.5171527862548828
# Given: _________doe, Predicted: enday______
# Given: _________yet, Predicted: eraay______
# Given: ___respected, Predicted: ereereessay
# Given: ________trip, Predicted: oissay_____
# Given: ____snapshot, Predicted: aanieenaay_
# Given: ____minority, Predicted: initinsaay_
# Given: ____cosmetic, Predicted: ertitestay_
# Given: ___forbidden, Predicted: oriineesaay
# Given: ______notice, Predicted: orinesay___
# Given: ____ultimate, Predicted: iriinensay_
#
# epoch: 3000, loss: 1.6851814985275269
# Given: _________doe, Predicted: orday______
# Given: _________yet, Predicted: eraay______
# Given: ___respected, Predicted: eeeereersay
# Given: ________trip, Predicted: oonsay_____
# Given: ____snapshot, Predicted: oatiiensay_
# Given: ____minority, Predicted: iniiinecay_
# Given: ____cosmetic, Predicted: oniinissay_
# Given: ___forbidden, Predicted: oniiniencay
# Given: ______notice, Predicted: onineray___
# Given: ____ultimate, Predicted: iniinansay_
#
# epoch: 3500, loss: 1.1573207378387451
# Given: _________doe, Predicted: onday______
# Given: _________yet, Predicted: eraay______
# Given: ___respected, Predicted: ereereessay
# Given: ________trip, Predicted: iissay_____
# Given: ____snapshot, Predicted: aattiessay_
# Given: ____minority, Predicted: iniiinecay_
# Given: ____cosmetic, Predicted: osteressay_
# Given: ___forbidden, Predicted: oniineenaay
# Given: ______notice, Predicted: ininecay___
# Given: ____ultimate, Predicted: uttaaalsay_
#
# epoch: 4000, loss: 1.4939125776290894
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: edsay______
# Given: ___respected, Predicted: ereeriersay
# Given: ________trip, Predicted: iitsay_____
# Given: ____snapshot, Predicted: atttiossay_
# Given: ____minority, Predicted: iniiinysay_
# Given: ____cosmetic, Predicted: ortirirsay_
# Given: ___forbidden, Predicted: oroinoenaay
# Given: ______notice, Predicted: ininenay___
# Given: ____ultimate, Predicted: ittaaaleay_
#
# epoch: 4500, loss: 0.9198694229125977
# Given: _________doe, Predicted: ooday______
# Given: _________yet, Predicted: erpay______
# Given: ___respected, Predicted: eseertessay
# Given: ________trip, Predicted: oottay_____
# Given: ____snapshot, Predicted: utstuussay_
# Given: ____minority, Predicted: onstinssay_
# Given: ____cosmetic, Predicted: ottttittay_
# Given: ___forbidden, Predicted: orooneerpay
# Given: ______notice, Predicted: orineray___
# Given: ____ultimate, Predicted: uttaaaleay_
#
# epoch: 5000, loss: 0.7527522444725037
# Given: _________doe, Predicted: orday______
# Given: _________yet, Predicted: edaay______
# Given: ___respected, Predicted: ereertersay
# Given: ________trip, Predicted: oittay_____
# Given: ____snapshot, Predicted: aatttossay_
# Given: ____minority, Predicted: onilinscay_
# Given: ____cosmetic, Predicted: ortolissay_
# Given: ___forbidden, Predicted: orooneercay
# Given: ______notice, Predicted: oninenay___
# Given: ____ultimate, Predicted: ittaaaleay_
#
# epoch: 5500, loss: 1.6261862516403198
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: esaay______
# Given: ___respected, Predicted: eseertersay
# Given: ________trip, Predicted: iitsay_____
# Given: ____snapshot, Predicted: atsttossay_
# Given: ____minority, Predicted: inttttycay_
# Given: ____cosmetic, Predicted: ostecirsay_
# Given: ___forbidden, Predicted: orconeercay
# Given: ______notice, Predicted: oninenay___
# Given: ____ultimate, Predicted: ittiaateay_
#
# epoch: 6000, loss: 0.58934086561203
# Given: _________doe, Predicted: orday______
# Given: _________yet, Predicted: edaay______
# Given: ___respected, Predicted: eseestersay
# Given: ________trip, Predicted: iittay_____
# Given: ____snapshot, Predicted: aassuossay_
# Given: ____minority, Predicted: inglitymay_
# Given: ____cosmetic, Predicted: osticittay_
# Given: ___forbidden, Predicted: onmineedday
# Given: ______notice, Predicted: oninenay___
# Given: ____ultimate, Predicted: ittiaateay_
#
# epoch: 6500, loss: 0.41445648670196533
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: edaay______
# Given: ___respected, Predicted: eseectersay
# Given: ________trip, Predicted: rittay_____
# Given: ____snapshot, Predicted: aasshonsay_
# Given: ____minority, Predicted: ingcicycay_
# Given: ____cosmetic, Predicted: osteciccay_
# Given: ___forbidden, Predicted: onminienbay
# Given: ______notice, Predicted: oninenay___
# Given: ____ultimate, Predicted: ittiaaleay_
#
# epoch: 7000, loss: 1.5611180067062378
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: esaay______
# Given: ___respected, Predicted: eseerterpay
# Given: ________trip, Predicted: rittay_____
# Given: ____snapshot, Predicted: aasstessay_
# Given: ____minority, Predicted: inrritypay_
# Given: ____cosmetic, Predicted: ostericcay_
# Given: ___forbidden, Predicted: ormineenaay
# Given: ______notice, Predicted: oninenay___
# Given: ____ultimate, Predicted: ittiaaleay_
#
# epoch: 7500, loss: 0.7898496985435486
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: etaay______
# Given: ___respected, Predicted: esperterday
# Given: ________trip, Predicted: rittay_____
# Given: ____snapshot, Predicted: aasthorsay_
# Given: ____minority, Predicted: ingtttyray_
# Given: ____cosmetic, Predicted: osteciccay_
# Given: ___forbidden, Predicted: ormineencay
# Given: ______notice, Predicted: oninenay___
# Given: ____ultimate, Predicted: ittiaaleay_
#
# epoch: 8000, loss: 0.5997425317764282
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: etaay______
# Given: ___respected, Predicted: eseerterray
# Given: ________trip, Predicted: rittay_____
# Given: ____snapshot, Predicted: aasthossay_
# Given: ____minority, Predicted: inorityray_
# Given: ____cosmetic, Predicted: osteticcay_
# Given: ___forbidden, Predicted: ormuneenaay
# Given: ______notice, Predicted: onioenay___
# Given: ____ultimate, Predicted: ittitateay_
#
# epoch: 8500, loss: 1.7460849285125732
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: etyay______
# Given: ___respected, Predicted: escectersay
# Given: ________trip, Predicted: rittay_____
# Given: ____snapshot, Predicted: aasthossay_
# Given: ____minority, Predicted: inorttyhay_
# Given: ____cosmetic, Predicted: osteciccay_
# Given: ___forbidden, Predicted: ommineencay
# Given: ______notice, Predicted: otioenay___
# Given: ____ultimate, Predicted: ittilaleay_
# epoch: 9000, loss: 0.441118985414505
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: etyay______
# Given: ___respected, Predicted: eseecterray
# Given: ________trip, Predicted: rittay_____
# Given: ____snapshot, Predicted: aasthossay_
# Given: ____minority, Predicted: inorttyhay_
# Given: ____cosmetic, Predicted: osteciccay_
# Given: ___forbidden, Predicted: ommudeedbay
# Given: ______notice, Predicted: otioenay___
# Given: ____ultimate, Predicted: uttiaateay_
#
# epoch: 9500, loss: 0.39260366559028625
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: etyay______
# Given: ___respected, Predicted: eseectereay
# Given: ________trip, Predicted: rittay_____
# Given: ____snapshot, Predicted: aastoetsay_
# Given: ____minority, Predicted: inrritycay_
# Given: ____cosmetic, Predicted: osteciccay_
# Given: ___forbidden, Predicted: ormineencay
# Given: ______notice, Predicted: oninenay___
# Given: ____ultimate, Predicted: uttiaeeeay_
#
# epoch: 10000, loss: 0.305949866771698
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: etaay______
# Given: ___respected, Predicted: epperterray
# Given: ________trip, Predicted: rittay_____
# Given: ____snapshot, Predicted: aasttotsay_
# Given: ____minority, Predicted: inorytyhay_
# Given: ____cosmetic, Predicted: osteciccay_
# Given: ___forbidden, Predicted: orddneencay
# Given: ______notice, Predicted: otioenay___
# Given: ____ultimate, Predicted: ultiaaleay_
#
# epoch: 10500, loss: 0.9311418533325195
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: etaay______
# Given: ___respected, Predicted: especterray
# Given: ________trip, Predicted: rittay_____
# Given: ____snapshot, Predicted: aasshonsay_
# Given: ____minority, Predicted: inoritymay_
# Given: ____cosmetic, Predicted: osceciccay_
# Given: ___forbidden, Predicted: ormineencay
# Given: ______notice, Predicted: oticenay___
# Given: ____ultimate, Predicted: ultiaaleay_
#
# epoch: 11000, loss: 0.3848642110824585
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: etyay______
# Given: ___respected, Predicted: espectedray
# Given: ________trip, Predicted: rittay_____
# Given: ____snapshot, Predicted: aasthotsay_
# Given: ____minority, Predicted: inorttymay_
# Given: ____cosmetic, Predicted: osteciccay_
# Given: ___forbidden, Predicted: ormdneenbay
# Given: ______notice, Predicted: oticenay___
# Given: ____ultimate, Predicted: ultiteteay_
#
# epoch: 11500, loss: 0.6991243958473206
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: etyay______
# Given: ___respected, Predicted: escerterray
# Given: ________trip, Predicted: rittay_____
# Given: ____snapshot, Predicted: aasthotsay_
# Given: ____minority, Predicted: inorityaay_
# Given: ____cosmetic, Predicted: osteciccay_
# Given: ___forbidden, Predicted: orddddedcay
# Given: ______notice, Predicted: oticenay___
# Given: ____ultimate, Predicted: uttiaareay_
#
# epoch: 12000, loss: 0.1678653359413147
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: etyay______
# Given: ___respected, Predicted: espectedday
# Given: ________trip, Predicted: rittay_____
# Given: ____snapshot, Predicted: aasstotsay_
# Given: ____minority, Predicted: inoritymay_
# Given: ____cosmetic, Predicted: osccciccay_
# Given: ___forbidden, Predicted: ormdddenbay
# Given: ______notice, Predicted: oticenay___
# Given: ____ultimate, Predicted: ultileteay_
#
# epoch: 12500, loss: 0.44910115003585815
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: etyay______
# Given: ___respected, Predicted: eseectedray
# Given: ________trip, Predicted: rittay_____
# Given: ____snapshot, Predicted: aasstossay_
# Given: ____minority, Predicted: inoritymay_
# Given: ____cosmetic, Predicted: osceciccay_
# Given: ___forbidden, Predicted: ormddeedcay
# Given: ______notice, Predicted: oticenay___
# Given: ____ultimate, Predicted: ultilateay_
#
# epoch: 13000, loss: 0.5413410663604736
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: etyay______
# Given: ___respected, Predicted: especterray
# Given: ________trip, Predicted: rittay_____
# Given: ____snapshot, Predicted: aassootsay_
# Given: ____minority, Predicted: inoritymay_
# Given: ____cosmetic, Predicted: ospeciccay_
# Given: ___forbidden, Predicted: rrdddeeccay
# Given: ______notice, Predicted: ocicenay___
# Given: ____ultimate, Predicted: ultibareay_
#
# epoch: 13500, loss: 0.14458003640174866
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: etyay______
# Given: ___respected, Predicted: especeedray
# Given: ________trip, Predicted: rittay_____
# Given: ____snapshot, Predicted: aassoossay_
# Given: ____minority, Predicted: inoritymay_
# Given: ____cosmetic, Predicted: ospeccccay_
# Given: ___forbidden, Predicted: rrddneemaay
# Given: ______notice, Predicted: oticeaay___
# Given: ____ultimate, Predicted: uttimateay_
#
# epoch: 14000, loss: 0.19078049063682556
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: etyay______
# Given: ___respected, Predicted: espectedray
# Given: ________trip, Predicted: rittay_____
# Given: ____snapshot, Predicted: aassoossay_
# Given: ____minority, Predicted: inoritynay_
# Given: ____cosmetic, Predicted: ospeciccay_
# Given: ___forbidden, Predicted: rrddneencay
# Given: ______notice, Predicted: oticenay___
# Given: ____ultimate, Predicted: ultitateay_
#
# epoch: 14500, loss: 0.10292544960975647
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: etyay______
# Given: ___respected, Predicted: espectedray
# Given: ________trip, Predicted: riptay_____
# Given: ____snapshot, Predicted: aasstotsay_
# Given: ____minority, Predicted: inorityfay_
# Given: ____cosmetic, Predicted: ospeciccay_
# Given: ___forbidden, Predicted: ordddeeffay
# Given: ______notice, Predicted: oticenay___
# Given: ____ultimate, Predicted: ultibaeeay_
#
# epoch: 15000, loss: 0.08295539021492004
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: etyay______
# Given: ___respected, Predicted: especeedsay
# Given: ________trip, Predicted: riptay_____
# Given: ____snapshot, Predicted: aapstotsay_
# Given: ____minority, Predicted: inoritymay_
# Given: ____cosmetic, Predicted: osmeclccay_
# Given: ___forbidden, Predicted: rrmddeedfay
# Given: ______notice, Predicted: oticenay___
# Given: ____ultimate, Predicted: ultiaeeeay_
#
# epoch: 15500, loss: 0.34176182746887207
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: etyay______
# Given: ___respected, Predicted: espectedday
# Given: ________trip, Predicted: rittay_____
# Given: ____snapshot, Predicted: aasstotsay_
# Given: ____minority, Predicted: inoritymay_
# Given: ____cosmetic, Predicted: osmeccccay_
# Given: ___forbidden, Predicted: ormddeemfay
# Given: ______notice, Predicted: oticenay___
# Given: ____ultimate, Predicted: ultimaeeay_
#
# epoch: 16000, loss: 0.03350518271327019
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: etyay______
# Given: ___respected, Predicted: espectedray
# Given: ________trip, Predicted: rittay_____
# Given: ____snapshot, Predicted: aasshotsay_
# Given: ____minority, Predicted: inorftyfay_
# Given: ____cosmetic, Predicted: osmeciccay_
# Given: ___forbidden, Predicted: ormddnencay
# Given: ______notice, Predicted: oticenay___
# Given: ____ultimate, Predicted: ultibeeeay_
#
# epoch: 16500, loss: 0.15215125679969788
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: etyay______
# Given: ___respected, Predicted: espectedray
# Given: ________trip, Predicted: riptay_____
# Given: ____snapshot, Predicted: aasstotsay_
# Given: ____minority, Predicted: inoritymay_
# Given: ____cosmetic, Predicted: ospeciccay_
# Given: ___forbidden, Predicted: ormdddenfay
# Given: ______notice, Predicted: oticenay___
# Given: ____ultimate, Predicted: ultibateay_
#
# epoch: 17000, loss: 0.044287193566560745
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: etyay______
# Given: ___respected, Predicted: espectedray
# Given: ________trip, Predicted: rittay_____
# Given: ____snapshot, Predicted: aasstotsay_
# Given: ____minority, Predicted: inorityfay_
# Given: ____cosmetic, Predicted: ospeciccay_
# Given: ___forbidden, Predicted: ormddnenfay
# Given: ______notice, Predicted: oticenay___
# Given: ____ultimate, Predicted: uttiaaeeay_
#
# epoch: 17500, loss: 0.44612520933151245
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: etyay______
# Given: ___respected, Predicted: especterray
# Given: ________trip, Predicted: riptay_____
# Given: ____snapshot, Predicted: aasstotsay_
# Given: ____minority, Predicted: inoritymay_
# Given: ____cosmetic, Predicted: ospeciccay_
# Given: ___forbidden, Predicted: ormdddemfay
# Given: ______notice, Predicted: oticenay___
# Given: ____ultimate, Predicted: ultiaareay_
# epoch: 18000, loss: 0.07681002467870712
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: etyay______
# Given: ___respected, Predicted: espectedray
# Given: ________trip, Predicted: riptay_____
# Given: ____snapshot, Predicted: aasstotsay_
# Given: ____minority, Predicted: inoritymay_
# Given: ____cosmetic, Predicted: oseeciccay_
# Given: ___forbidden, Predicted: ormdddencay
# Given: ______notice, Predicted: oticenay___
# Given: ____ultimate, Predicted: ultimateay_
#
# epoch: 18500, loss: 0.009101846255362034
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: etyay______
# Given: ___respected, Predicted: espectessay
# Given: ________trip, Predicted: riptay_____
# Given: ____snapshot, Predicted: aapstotsay_
# Given: ____minority, Predicted: inoritymay_
# Given: ____cosmetic, Predicted: ospeticcay_
# Given: ___forbidden, Predicted: ormdddelfay
# Given: ______notice, Predicted: oticenay___
# Given: ____ultimate, Predicted: ultimateay_
#
# epoch: 19000, loss: 0.07314101606607437
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: etyay______
# Given: ___respected, Predicted: espectedray
# Given: ________trip, Predicted: rittay_____
# Given: ____snapshot, Predicted: aapshotsay_
# Given: ____minority, Predicted: inoritymay_
# Given: ____cosmetic, Predicted: ospeticcay_
# Given: ___forbidden, Predicted: ormddeelaay
# Given: ______notice, Predicted: oticenay___
# Given: ____ultimate, Predicted: ultimateay_
#
# epoch: 19500, loss: 0.02638082578778267
# Given: _________doe, Predicted: oeday______
# Given: _________yet, Predicted: etyay______
# Given: ___respected, Predicted: espectedray
# Given: ________trip, Predicted: riptay_____
# Given: ____snapshot, Predicted: aapshossay_
# Given: ____minority, Predicted: inoritymay_
# Given: ____cosmetic, Predicted: ospeticcay_
# Given: ___forbidden, Predicted: ormddeenfay
# Given: ______notice, Predicted: oticenay___
# Given: ____ultimate, Predicted: ultimateay_
